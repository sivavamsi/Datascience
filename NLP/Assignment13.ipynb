# %%
path = "http://www.cs.cornell.edu/~cristian/data/cornell_movie_dialogs_corpus.zip"

# %%
#!pip install wget

# %%
import wget
wget.download(path,"cornell_movie_dialogs_corpus.zip")
# Out:
# 'cornell_movie_dialogs_corpus (1).zip'

# %%
import zipfile
with zipfile.ZipFile("cornell_movie_dialogs_corpus.zip", 'r') as zip_ref:
    zip_ref.extractall("cornell_movie_dialogs_corpus")

# %%
cd cornell_movie_dialogs_corpus
# Out:
# /content/cornell_movie_dialogs_corpus

# %%
cd cornell movie-dialogs corpus
# Out:
# /content/cornell_movie_dialogs_corpus/cornell movie-dialogs corpus

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

import torch
from torch.jit import script, trace
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import csv
import random
import re
import os
import unicodedata
import codecs
from io import open
import itertools
import math


USE_CUDA = torch.cuda.is_available()
device = torch.device("cuda" if USE_CUDA else "cpu")

# %%
def printLines(file, n=10):
    with open(file, 'rb') as datafile:
        lines = datafile.readlines()
    for line in lines[:n]:
        print(line)

# %%
printLines( "movie_lines.txt")
# Out:
# b'L1045 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ They do not!\n'
# b'L1044 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ They do to!\n'
# b'L985 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I hope so.\n'
# b'L984 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ She okay?\n'
# b"L925 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Let's go.\n"
# b'L924 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ Wow\n'
# b"L872 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Okay -- you're gonna need to learn how to lie.\n"
# b'L871 +++$+++ u2 +++$+++ m0 +++$+++ CAMERON +++$+++ No\n'
# b'L870 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ I\'m kidding.  You know how sometimes you just become this "persona"?  And you don\'t know how to quit?\n'
# b'L869 +++$+++ u0 +++$+++ m0 +++$+++ BIANCA +++$+++ Like my fear of wearing pastels?\n'

# %%
# Splits each line of the file into a dictionary of fields
def loadLines(fileName, fields):
    lines = {}
    with open(fileName, 'r', encoding='iso-8859-1') as f:
        for line in f:
            values = line.split(" +++$+++ ")
            # Extract fields
            lineObj = {}
            for i, field in enumerate(fields):
                lineObj[field] = values[i]
            lines[lineObj['lineID']] = lineObj
    return lines


# Groups fields of lines from `loadLines` into conversations based on *movie_conversations.txt*
def loadConversations(fileName, lines, fields):
    conversations = []
    with open(fileName, 'r', encoding='iso-8859-1') as f:
        for line in f:
            values = line.split(" +++$+++ ")
            # Extract fields
            convObj = {}
            for i, field in enumerate(fields):
                convObj[field] = values[i]
            # Convert string to list (convObj["utteranceIDs"] == "['L598485', 'L598486', ...]")
            utterance_id_pattern = re.compile('L[0-9]+')
            lineIds = utterance_id_pattern.findall(convObj["utteranceIDs"])
            # Reassemble lines
            convObj["lines"] = []
            for lineId in lineIds:
                convObj["lines"].append(lines[lineId])
            conversations.append(convObj)
    return conversations


# Extracts pairs of sentences from conversations
def extractSentencePairs(conversations):
    qa_pairs = []
    for conversation in conversations:
        # Iterate over all the lines of the conversation
        for i in range(len(conversation["lines"]) - 1):  # We ignore the last line (no answer for it)
            inputLine = conversation["lines"][i]["text"].strip()
            targetLine = conversation["lines"][i+1]["text"].strip()
            # Filter wrong samples (if one of the lists is empty)
            if inputLine and targetLine:
                qa_pairs.append([inputLine, targetLine])
    return qa_pairs

# %%
# Define path to new file
datafile =  "formatted_movie_lines.txt"

delimiter = '\t'
# Unescape the delimiter
delimiter = str(codecs.decode(delimiter, "unicode_escape"))

# Initialize lines dict, conversations list, and field ids
lines = {}
conversations = []
MOVIE_LINES_FIELDS = ["lineID", "characterID", "movieID", "character", "text"]
MOVIE_CONVERSATIONS_FIELDS = ["character1ID", "character2ID", "movieID", "utteranceIDs"]

# Load lines and process conversations
print("\nProcessing corpus...")
lines = loadLines( "movie_lines.txt", MOVIE_LINES_FIELDS)
print("\nLoading conversations...")
conversations = loadConversations( "movie_conversations.txt",
                                  lines, MOVIE_CONVERSATIONS_FIELDS)

# Write new csv file
print("\nWriting newly formatted file...")
with open(datafile, 'w', encoding='utf-8') as outputfile:
    writer = csv.writer(outputfile, delimiter=delimiter, lineterminator='\n')
    for pair in extractSentencePairs(conversations):
        writer.writerow(pair)

# Print a sample of lines
print("\nSample lines from file:")
printLines(datafile)
# Out:
# Processing corpus...
#
# Loading conversations...
#
# Writing newly formatted file...
#
# Sample lines from file:
# b"Can we make this quick?  Roxanne Korrine and Andrew Barrett are having an incredibly horrendous public break- up on the quad.  Again.\tWell, I thought we'd start with pronunciation, if that's okay with you.\n"
# b"Well, I thought we'd start with pronunciation, if that's okay with you.\tNot the hacking and gagging and spitting part.  Please.\n"
# b"Not the hacking and gagging and spitting part.  Please.\tOkay... then how 'bout we try out some French cuisine.  Saturday?  Night?\n"
# b"You're asking me out.  That's so cute. What's your name again?\tForget it.\n"
# b"No, no, it's my fault -- we didn't have a proper introduction ---\tCameron.\n"
# b"Cameron.\tThe thing is, Cameron -- I'm at the mercy of a particularly hideous breed of loser.  My sister.  I can't date until she does.\n"
# b"The thing is, Cameron -- I'm at the mercy of a particularly hideous breed of loser.  My sister.  I can't date until she does.\tSeems like she could get a date easy enough...\n"
# b'Why?\tUnsolved mystery.  She used to be really popular when she started high school, then it was just like she got sick of it or something.\n'
# b"Unsolved mystery.  She used to be really popular when she started high school, then it was just like she got sick of it or something.\tThat's a shame.\n"
# b'Gosh, if only we could find Kat a boyfriend...\tLet me see what I can do.\n'

# %%
# Default word tokens
PAD_token = 0  # Used for padding short sentences
SOS_token = 1  # Start-of-sentence token
EOS_token = 2  # End-of-sentence token

class Voc:
    def __init__(self, name):
        self.name = name
        self.trimmed = False
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3  # Count SOS, EOS, PAD

    def addSentence(self, sentence):
        for word in sentence.split(' '):
            self.addWord(word)

    def addWord(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.num_words
            self.word2count[word] = 1
            self.index2word[self.num_words] = word
            self.num_words += 1
        else:
            self.word2count[word] += 1

    # Remove words below a certain count threshold
    def trim(self, min_count):
        if self.trimmed:
            return
        self.trimmed = True

        keep_words = []

        for k, v in self.word2count.items():
            if v >= min_count:
                keep_words.append(k)

        print('keep_words {} / {} = {:.4f}'.format(
            len(keep_words), len(self.word2index), len(keep_words) / len(self.word2index)
        ))

        # Reinitialize dictionaries
        self.word2index = {}
        self.word2count = {}
        self.index2word = {PAD_token: "PAD", SOS_token: "SOS", EOS_token: "EOS"}
        self.num_words = 3 # Count default tokens

        for word in keep_words:
            self.addWord(word)

# %%
corpus_name="cornell movie-dialogs corpus"
corpus = os.path.join( corpus_name)

# %%
MAX_LENGTH = 10  # Maximum sentence length to consider

# Turn a Unicode string to plain ASCII, thanks to
# https://stackoverflow.com/a/518232/2809427
def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
    )

# Lowercase, trim, and remove non-letter characters
def normalizeString(s):
    s = unicodeToAscii(s.lower().strip())
    s = re.sub(r"([.!?])", r" \1", s)
    s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
    s = re.sub(r"\s+", r" ", s).strip()
    return s

# Read query/response pairs and return a voc object
def readVocs(datafile, corpus_name):
    print("Reading lines...")
    # Read the file and split into lines
    lines = open(datafile, encoding='utf-8').\
        read().strip().split('\n')
    # Split every line into pairs and normalize
    pairs = [[normalizeString(s) for s in l.split('\t')] for l in lines]
    voc = Voc(corpus_name)
    return voc, pairs

# Returns True iff both sentences in a pair 'p' are under the MAX_LENGTH threshold
def filterPair(p):
    # Input sequences need to preserve the last word for EOS token
    return len(p[0].split(' ')) < MAX_LENGTH and len(p[1].split(' ')) < MAX_LENGTH

# Filter pairs using filterPair condition
def filterPairs(pairs):
    return [pair for pair in pairs if filterPair(pair)]

# Using the functions defined above, return a populated voc object and pairs list
def loadPrepareData(corpus, corpus_name, datafile, save_dir):
    print("Start preparing training data ...")
    voc, pairs = readVocs(datafile, corpus_name)
    print("Read {!s} sentence pairs".format(len(pairs)))
    pairs = filterPairs(pairs)
    print("Trimmed to {!s} sentence pairs".format(len(pairs)))
    print("Counting words...")
    for pair in pairs:
        voc.addSentence(pair[0])
        voc.addSentence(pair[1])
    print("Counted words:", voc.num_words)
    return voc, pairs


# Load/Assemble voc and pairs
save_dir = os.path.join("data", "save")
voc, pairs = loadPrepareData(corpus, corpus_name, datafile, save_dir)
# Print some pairs to validate
print("\npairs:")
for pair in pairs[:10]:
    print(pair)
# Out:
# Start preparing training data ...
# Reading lines...
# Read 221282 sentence pairs
# Trimmed to 64271 sentence pairs
# Counting words...
# Counted words: 18008
#
# pairs:
# ['there .', 'where ?']
# ['you have my word . as a gentleman', 'you re sweet .']
# ['hi .', 'looks like things worked out tonight huh ?']
# ['you know chastity ?', 'i believe we share an art instructor']
# ['have fun tonight ?', 'tons']
# ['well no . . .', 'then that s all you had to say .']
# ['then that s all you had to say .', 'but']
# ['but', 'you always been this selfish ?']
# ['do you listen to this crap ?', 'what crap ?']
# ['what good stuff ?', 'the real you .']

# %%
len(voc.word2index.keys())
# Out:
# 18005

# %%
MIN_COUNT = 3    # Minimum word count threshold for trimming

def trimRareWords(voc, pairs, MIN_COUNT):
    # Trim words used under the MIN_COUNT from the voc
    voc.trim(MIN_COUNT)
    # Filter out pairs with trimmed words
    keep_pairs = []
    for pair in pairs:
        input_sentence = pair[0]
        output_sentence = pair[1]
        keep_input = True
        keep_output = True
        # Check input sentence
        for word in input_sentence.split(' '):
            if word not in voc.word2index:
                keep_input = False
                break
        # Check output sentence
        for word in output_sentence.split(' '):
            if word not in voc.word2index:
                keep_output = False
                break

        # Only keep pairs that do not contain trimmed word(s) in their input or output sentence
        if keep_input and keep_output:
            keep_pairs.append(pair)

    print("Trimmed from {} pairs to {}, {:.4f} of total".format(len(pairs), len(keep_pairs), len(keep_pairs) / len(pairs)))
    return keep_pairs


# Trim voc and pairs
pairs = trimRareWords(voc, pairs, MIN_COUNT)
# Out:
# keep_words 7823 / 18005 = 0.4345
# Trimmed from 64271 pairs to 53165, 0.8272 of total

# %%
len(pairs)
# Out:
# 53165

# %%
pairs[:10]
# Out:
# [['there .', 'where ?'],
#  ['you have my word . as a gentleman', 'you re sweet .'],
#  ['hi .', 'looks like things worked out tonight huh ?'],
#  ['have fun tonight ?', 'tons'],
#  ['well no . . .', 'then that s all you had to say .'],
#  ['then that s all you had to say .', 'but'],
#  ['but', 'you always been this selfish ?'],
#  ['do you listen to this crap ?', 'what crap ?'],
#  ['what good stuff ?', 'the real you .'],
#  ['wow', 'let s go .']]

# %%
def indexesFromSentence(voc, sentence):
    return [voc.word2index[word] for word in sentence.split(' ')] + [EOS_token]


def zeroPadding(l, fillvalue=PAD_token):
    return list(itertools.zip_longest(*l, fillvalue=fillvalue))

def binaryMatrix(l, value=PAD_token):
    m = []
    for i, seq in enumerate(l):
        m.append([])
        for token in seq:
            if token == PAD_token:
                m[i].append(0)
            else:
                m[i].append(1)
    return m

# Returns padded input sequence tensor and lengths
def inputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    lengths = torch.tensor([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    padVar = torch.LongTensor(padList)
    return padVar, lengths

# Returns padded target sequence tensor, padding mask, and max target length
def outputVar(l, voc):
    indexes_batch = [indexesFromSentence(voc, sentence) for sentence in l]
    max_target_len = max([len(indexes) for indexes in indexes_batch])
    padList = zeroPadding(indexes_batch)
    mask = binaryMatrix(padList)
    mask = torch.BoolTensor(mask)
    padVar = torch.LongTensor(padList)
    return padVar, mask, max_target_len

# Returns all items for a given batch of pairs
def batch2TrainData(voc, pair_batch):
    pair_batch.sort(key=lambda x: len(x[0].split(" ")), reverse=True)
    input_batch, output_batch = [], []
    for pair in pair_batch:
        input_batch.append(pair[0])
        output_batch.append(pair[1])
    inp, lengths = inputVar(input_batch, voc)
    output, mask, max_target_len = outputVar(output_batch, voc)
    return inp.transpose(1,0 ), lengths, output.transpose(1,0 ), mask.transpose(1,0 ), max_target_len


# Example for validation
small_batch_size = 5
batches = batch2TrainData(voc, [random.choice(pairs) for _ in range(small_batch_size)])
input_variable, lengths, target_variable, mask, max_target_len = batches

print("input_variable:", input_variable)
print("lengths:", lengths)
print("target_variable:", target_variable)
print("mask:", mask)
print("max_target_len:", max_target_len)
# Out:
# input_variable: tensor([[ 122,   68,    7,    8,   12, 1841, 1255, 4488,    6,    2],
#         [2200,   25,   94,  117,    4,    4,    4,    2,    0,    0],
#         [ 591,   53, 1144,    4,  656,    4,    2,    0,    0,    0],
#         [   5,  102, 1786,    6,    2,    0,    0,    0,    0,    0],
#         [  67, 2023,    4,    2,    0,    0,    0,    0,    0,    0]])
# lengths: tensor([10,  8,  7,  5,  4])
# target_variable: tensor([[ 318,    4,    4,    4,    2,    0,    0,    0,    0],
#         [  94,  117,   50,    6,    2,    0,    0,    0,    0],
#         [ 692,   12, 1368,  203,  271,  117,   76,    6,    2],
#         [ 101,  191,  117,  169, 1762, 1763,    4,    2,    0],
#         [ 101,   37, 6369,   95,    4,    2,    0,    0,    0]])
# mask: tensor([[ True,  True,  True,  True,  True, False, False, False, False],
#         [ True,  True,  True,  True,  True, False, False, False, False],
#         [ True,  True,  True,  True,  True,  True,  True,  True,  True],
#         [ True,  True,  True,  True,  True,  True,  True,  True, False],
#         [ True,  True,  True,  True,  True,  True, False, False, False]])
# max_target_len: 9

# %%
class Encoder(nn.Module):
    def __init__(self, 
                 input_dim, 
                 hid_dim, 
                 n_layers, 
                 n_heads, 
                 pf_dim,
                 dropout, 
                 device,
                 max_length = 100):
        super().__init__()

        self.device = device
        
        self.tok_embedding = nn.Embedding(input_dim, hid_dim)
        self.pos_embedding = nn.Embedding(max_length, hid_dim)
        
        self.layers = nn.ModuleList([EncoderLayer(hid_dim, 
                                                  n_heads, 
                                                  pf_dim,
                                                  dropout, 
                                                  device) 
                                     for _ in range(n_layers)])
        
        self.dropout = nn.Dropout(dropout)
        
        self.scale = torch.sqrt(torch.FloatTensor([hid_dim])).to(device)
        
    def forward(self, src, src_mask):
        
        #src = [batch size, src len]
        #src_mask = [batch size, 1, 1, src len]
        
        batch_size = src.shape[0]
        src_len = src.shape[1]
        
        pos = torch.arange(0, src_len).unsqueeze(0).repeat(batch_size, 1).to(self.device)
        
        #pos = [batch size, src len]
        
        src = self.dropout((self.tok_embedding(src) * self.scale) + self.pos_embedding(pos))
        
        #src = [batch size, src len, hid dim]
        
        for layer in self.layers:
            src = layer(src, src_mask)
            
        #src = [batch size, src len, hid dim]
            
        return src

# %%
class EncoderLayer(nn.Module):
    def __init__(self, 
                 hid_dim, 
                 n_heads, 
                 pf_dim,  
                 dropout, 
                 device):
        super().__init__()
        
        self.self_attn_layer_norm = nn.LayerNorm(hid_dim)
        self.ff_layer_norm = nn.LayerNorm(hid_dim)
        self.self_attention = MultiHeadAttentionLayer(hid_dim, n_heads, dropout, device)
        self.positionwise_feedforward = PositionwiseFeedforwardLayer(hid_dim, 
                                                                     pf_dim, 
                                                                     dropout)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, src, src_mask):
        
        #src = [batch size, src len, hid dim]
        #src_mask = [batch size, 1, 1, src len] 
                
        #self attention
        _src, _ = self.self_attention(src, src, src, src_mask)
        
        #dropout, residual connection and layer norm
        src = self.self_attn_layer_norm(src + self.dropout(_src))
        
        #src = [batch size, src len, hid dim]
        
        #positionwise feedforward
        _src = self.positionwise_feedforward(src)
        
        #dropout, residual and layer norm
        src = self.ff_layer_norm(src + self.dropout(_src))
        
        #src = [batch size, src len, hid dim]
        
        return src

# %%
class MultiHeadAttentionLayer(nn.Module):
    def __init__(self, hid_dim, n_heads, dropout, device):
        super().__init__()
        
        assert hid_dim % n_heads == 0
        
        self.hid_dim = hid_dim
        self.n_heads = n_heads
        self.head_dim = hid_dim // n_heads
        
        self.fc_q = nn.Linear(hid_dim, hid_dim)
        self.fc_k = nn.Linear(hid_dim, hid_dim)
        self.fc_v = nn.Linear(hid_dim, hid_dim)
        
        self.fc_o = nn.Linear(hid_dim, hid_dim)
        
        self.dropout = nn.Dropout(dropout)
        
        self.scale = torch.sqrt(torch.FloatTensor([self.head_dim])).to(device)
        
    def forward(self, query, key, value, mask = None):
        
        batch_size = query.shape[0]
        
        #query = [batch size, query len, hid dim]
        #key = [batch size, key len, hid dim]
        #value = [batch size, value len, hid dim]
                
        Q = self.fc_q(query)
        K = self.fc_k(key)
        V = self.fc_v(value)
        
        #Q = [batch size, query len, hid dim]
        #K = [batch size, key len, hid dim]
        #V = [batch size, value len, hid dim]
                
        Q = Q.view(batch_size, -1, self.n_heads, self.head_dim).permute(0, 2, 1, 3)
        K = K.view(batch_size, -1, self.n_heads, self.head_dim).permute(0, 2, 1, 3)
        V = V.view(batch_size, -1, self.n_heads, self.head_dim).permute(0, 2, 1, 3)
        
        #Q = [batch size, n heads, query len, head dim]
        #K = [batch size, n heads, key len, head dim]
        #V = [batch size, n heads, value len, head dim]
                
        energy = torch.matmul(Q, K.permute(0, 1, 3, 2)) / self.scale
        
        #energy = [batch size, n heads, query len, key len]
        
        if mask is not None:
            energy = energy.masked_fill(mask == 0, -1e10)
        
        attention = torch.softmax(energy, dim = -1)
                
        #attention = [batch size, n heads, query len, key len]
                
        x = torch.matmul(self.dropout(attention), V)
        
        #x = [batch size, n heads, query len, head dim]
        
        x = x.permute(0, 2, 1, 3).contiguous()
        
        #x = [batch size, query len, n heads, head dim]
        
        x = x.view(batch_size, -1, self.hid_dim)
        
        #x = [batch size, query len, hid dim]
        
        x = self.fc_o(x)
        
        #x = [batch size, query len, hid dim]
        
        return x, attention

# %%
class PositionwiseFeedforwardLayer(nn.Module):
    def __init__(self, hid_dim, pf_dim, dropout):
        super().__init__()
        
        self.fc_1 = nn.Linear(hid_dim, pf_dim)
        self.fc_2 = nn.Linear(pf_dim, hid_dim)
        
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, x):
        
        #x = [batch size, seq len, hid dim]
        
        x = self.dropout(torch.relu(self.fc_1(x)))
        
        #x = [batch size, seq len, pf dim]
        
        x = self.fc_2(x)
        
        #x = [batch size, seq len, hid dim]
        
        return x

# %%
class Decoder(nn.Module):
    def __init__(self, 
                 output_dim, 
                 hid_dim, 
                 n_layers, 
                 n_heads, 
                 pf_dim, 
                 dropout, 
                 device,
                 max_length = 100):
        super().__init__()
        
        self.device = device
        
        self.tok_embedding = nn.Embedding(output_dim, hid_dim)
        self.pos_embedding = nn.Embedding(max_length, hid_dim)
        
        self.layers = nn.ModuleList([DecoderLayer(hid_dim, 
                                                  n_heads, 
                                                  pf_dim, 
                                                  dropout, 
                                                  device)
                                     for _ in range(n_layers)])
        
        self.fc_out = nn.Linear(hid_dim, output_dim)
        
        self.dropout = nn.Dropout(dropout)
        
        self.scale = torch.sqrt(torch.FloatTensor([hid_dim])).to(device)
        
    def forward(self, trg, enc_src, trg_mask, src_mask):
        
        #trg = [batch size, trg len]
        #enc_src = [batch size, src len, hid dim]
        #trg_mask = [batch size, 1, trg len, trg len]
        #src_mask = [batch size, 1, 1, src len]
                
        batch_size = trg.shape[0]
        trg_len = trg.shape[1]
        
        pos = torch.arange(0, trg_len).unsqueeze(0).repeat(batch_size, 1).to(self.device)
                            
        #pos = [batch size, trg len]
            
        trg = self.dropout((self.tok_embedding(trg) * self.scale) + self.pos_embedding(pos))
                
        #trg = [batch size, trg len, hid dim]
        
        for layer in self.layers:
            trg, attention = layer(trg, enc_src, trg_mask, src_mask)
        
        #trg = [batch size, trg len, hid dim]
        #attention = [batch size, n heads, trg len, src len]
        
        output = self.fc_out(trg)
        
        #output = [batch size, trg len, output dim]
            
        return output, attention

# %%
class DecoderLayer(nn.Module):
    def __init__(self, 
                 hid_dim, 
                 n_heads, 
                 pf_dim, 
                 dropout, 
                 device):
        super().__init__()
        
        self.self_attn_layer_norm = nn.LayerNorm(hid_dim)
        self.enc_attn_layer_norm = nn.LayerNorm(hid_dim)
        self.ff_layer_norm = nn.LayerNorm(hid_dim)
        self.self_attention = MultiHeadAttentionLayer(hid_dim, n_heads, dropout, device)
        self.encoder_attention = MultiHeadAttentionLayer(hid_dim, n_heads, dropout, device)
        self.positionwise_feedforward = PositionwiseFeedforwardLayer(hid_dim, 
                                                                     pf_dim, 
                                                                     dropout)
        self.dropout = nn.Dropout(dropout)
        
    def forward(self, trg, enc_src, trg_mask, src_mask):
        
        #trg = [batch size, trg len, hid dim]
        #enc_src = [batch size, src len, hid dim]
        #trg_mask = [batch size, 1, trg len, trg len]
        #src_mask = [batch size, 1, 1, src len]
        
        #self attention
        _trg, _ = self.self_attention(trg, trg, trg, trg_mask)
        
        #dropout, residual connection and layer norm
        trg = self.self_attn_layer_norm(trg + self.dropout(_trg))
            
        #trg = [batch size, trg len, hid dim]
            
        #encoder attention
        _trg, attention = self.encoder_attention(trg, enc_src, enc_src, src_mask)
        # query, key, value
        
        #dropout, residual connection and layer norm
        trg = self.enc_attn_layer_norm(trg + self.dropout(_trg))
                    
        #trg = [batch size, trg len, hid dim]
        
        #positionwise feedforward
        _trg = self.positionwise_feedforward(trg)
        
        #dropout, residual and layer norm
        trg = self.ff_layer_norm(trg + self.dropout(_trg))
        
        #trg = [batch size, trg len, hid dim]
        #attention = [batch size, n heads, trg len, src len]
        
        return trg, attention

# %%
class Seq2Seq(nn.Module):
    def __init__(self, 
                 encoder, 
                 decoder, 
                 src_pad_idx, 
                 trg_pad_idx, 
                 device):
        super().__init__()
        
        self.encoder = encoder
        self.decoder = decoder
        self.src_pad_idx = src_pad_idx
        self.trg_pad_idx = trg_pad_idx
        self.device = device
        
    def make_src_mask(self, src):
        
        #src = [batch size, src len]
        
        src_mask = (src != self.src_pad_idx).unsqueeze(1).unsqueeze(2)

        #src_mask = [batch size, 1, 1, src len]

        return src_mask
    
    def make_trg_mask(self, trg):
        
        #trg = [batch size, trg len]
        
        trg_pad_mask = (trg != self.trg_pad_idx).unsqueeze(1).unsqueeze(2)
        
        #trg_pad_mask = [batch size, 1, 1, trg len]
        
        trg_len = trg.shape[1]
        
        trg_sub_mask = torch.tril(torch.ones((trg_len, trg_len), device = self.device)).bool()
        
        #trg_sub_mask = [trg len, trg len]
            
        trg_mask = trg_pad_mask & trg_sub_mask
        
        #trg_mask = [batch size, 1, trg len, trg len]
        
        return trg_mask

    def forward(self, src, trg):
        
        #src = [batch size, src len]
        #trg = [batch size, trg len]
                
        src_mask = self.make_src_mask(src)
        trg_mask = self.make_trg_mask(trg)
        
        #src_mask = [batch size, 1, 1, src len]
        #trg_mask = [batch size, 1, trg len, trg len]
        
        enc_src = self.encoder(src, src_mask)
        
        #enc_src = [batch size, src len, hid dim]
                
        output, attention = self.decoder(trg, enc_src, trg_mask, src_mask)
        
        #output = [batch size, trg len, output dim]
        #attention = [batch size, n heads, trg len, src len]
        
        return output, attention

# %%
def maskNLLLoss(inp, target, mask):
    # print(inp.shape, target.shape, mask.sum())
    nTotal = mask.sum()
    crossEntropy = nn.CrossEntropyLoss(ignore_index = TRG_PAD_IDX)
    loss = crossEntropy(inp, target)
    loss = loss.to(device)
    return loss, nTotal.item()

def make_trg_mask(trg):
        
        #trg = [batch size, trg len]
        
        trg_pad_mask = (trg != TRG_PAD_IDX).unsqueeze(1).unsqueeze(2)
        
        #trg_pad_mask = [batch size, 1, 1, trg len]
        
        trg_len = trg.shape[1]
        
        trg_sub_mask = torch.tril(torch.ones((trg_len, trg_len), device = device)).bool()
        
        #trg_sub_mask = [trg len, trg len]
            
        trg_mask = trg_pad_mask & trg_sub_mask
        
        #trg_mask = [batch size, 1, trg len, trg len]
        
        return trg_mask

# %%
def train(input_variable, lengths, target_variable, mask, max_target_len, model,optimizer, criterion, batch_size, clip):
    model.train()
    
    n_totals = 0
    print_losses = []
    loss = 0
    input_variable = input_variable.to(device)
    target_variable = target_variable.to(device)
    trg_mask = make_trg_mask(target_variable)
    optimizer.zero_grad()
    output, _ = model(input_variable, target_variable[:,:-1])
    output_dim = output.shape[-1]
            
    output = output.contiguous().view(-1, output_dim)
    target_variable = target_variable[:,1:].contiguous().view(-1)
    mask_loss, nTotal = criterion(output, target_variable, trg_mask)
    mask_loss.backward()
        
    torch.nn.utils.clip_grad_norm_(model.parameters(), clip)
    
    optimizer.step()
    
    print_losses.append(mask_loss.item() * nTotal)
    n_totals += nTotal


    return sum(print_losses) / n_totals

# %%
def trainIters(model_name, voc, pairs, model, n_iteration, batch_size,optimizer, criterion, print_every, save_every, clip):
    l=[]
    # Load batches for each iteration
    training_batches = [batch2TrainData(voc, [random.choice(pairs) for _ in range(batch_size)])
                      for _ in range(n_iteration)]

    # Initializations
    print('Initializing ...')
    start_iteration = 1
    print_loss = 0
    # if loadFilename:
    #     start_iteration = checkpoint['iteration'] + 1

    # Training loop
    print("Training...")
    for iteration in range(start_iteration, n_iteration + 1):
        training_batch = training_batches[iteration - 1]
        # Extract fields from batch
        input_variable, lengths, target_variable, mask, max_target_len = training_batch

        # Run a training iteration with batch
        loss = train(input_variable, lengths, target_variable, mask, max_target_len, model,optimizer, criterion, batch_size, clip)
        
        print_loss += loss

        # Print progress
        if iteration % print_every == 0:
            print_loss_avg = print_loss / print_every
            print("Iteration: {}; Percent complete: {:.1f}%; Average loss: {:.4f}".format(iteration, iteration / n_iteration * 100, print_loss_avg))
            print_loss = 0
            l.append(print_loss_avg)

        #Save checkpoint
        if (iteration % save_every == 0):
            torch.save(model.state_dict(), model_name)
    return l

# %%
batch_size = 16
model_name = "cb_model.pt"
INPUT_DIM = voc.num_words
OUTPUT_DIM = voc.num_words
HID_DIM = 256
ENC_LAYERS = 3
DEC_LAYERS = 3
ENC_HEADS = 8
DEC_HEADS = 8
ENC_PF_DIM = 512
DEC_PF_DIM = 512
ENC_DROPOUT = 0.1
DEC_DROPOUT = 0.1

enc = Encoder(INPUT_DIM, 
              HID_DIM, 
              ENC_LAYERS, 
              ENC_HEADS, 
              ENC_PF_DIM, 
              ENC_DROPOUT, 
              device)

dec = Decoder(OUTPUT_DIM, 
              HID_DIM, 
              DEC_LAYERS, 
              DEC_HEADS, 
              DEC_PF_DIM, 
              DEC_DROPOUT, 
              device)
SRC_PAD_IDX = 0
TRG_PAD_IDX = 0

model = Seq2Seq(enc, dec, SRC_PAD_IDX, TRG_PAD_IDX, device).to(device)

def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

print(f'The model has {count_parameters(model):,} trainable parameters')

def initialize_weights(m):
    if hasattr(m, 'weight') and m.weight.dim() > 1:
        nn.init.xavier_uniform_(m.weight.data)

model.apply(initialize_weights);

LEARNING_RATE = 0.0001

optimizer = torch.optim.Adam(model.parameters(), lr = LEARNING_RATE)
# Out:
# The model has 10,023,058 trainable parameters

# %%
# Configure training/optimization
clip = 1

n_iteration = 4000
print_every = 1
save_every = 500
criterion = maskNLLLoss



# Run training iterations
print("Starting Training!")
l = trainIters(model_name, voc, pairs, model, n_iteration, batch_size,optimizer, criterion, print_every, save_every, clip)
# Out:
# Starting Training!
# Initializing ...
# Training...
# Iteration: 1; Percent complete: 0.0%; Average loss: 8.9666
# Iteration: 2; Percent complete: 0.1%; Average loss: 8.8696
# Iteration: 3; Percent complete: 0.1%; Average loss: 8.6364
# Iteration: 4; Percent complete: 0.1%; Average loss: 8.5980
# Iteration: 5; Percent complete: 0.1%; Average loss: 8.4381
# Iteration: 6; Percent complete: 0.1%; Average loss: 8.3685
# Iteration: 7; Percent complete: 0.2%; Average loss: 8.3425
# Iteration: 8; Percent complete: 0.2%; Average loss: 8.2755
# Iteration: 9; Percent complete: 0.2%; Average loss: 8.0720
# Iteration: 10; Percent complete: 0.2%; Average loss: 8.2209
# Iteration: 11; Percent complete: 0.3%; Average loss: 7.9352
# Iteration: 12; Percent complete: 0.3%; Average loss: 8.0665
# Iteration: 13; Percent complete: 0.3%; Average loss: 8.1290
# Iteration: 14; Percent complete: 0.4%; Average loss: 7.9862
# Iteration: 15; Percent complete: 0.4%; Average loss: 7.9919
# Iteration: 16; Percent complete: 0.4%; Average loss: 7.9393
# Iteration: 17; Percent complete: 0.4%; Average loss: 7.6356
# Iteration: 18; Percent complete: 0.4%; Average loss: 7.7114
# Iteration: 19; Percent complete: 0.5%; Average loss: 7.9028
# Iteration: 20; Percent complete: 0.5%; Average loss: 7.7065
# Iteration: 21; Percent complete: 0.5%; Average loss: 7.6790
# Iteration: 22; Percent complete: 0.5%; Average loss: 7.7466
# Iteration: 23; Percent complete: 0.6%; Average loss: 7.5141
# Iteration: 24; Percent complete: 0.6%; Average loss: 7.5797
# Iteration: 25; Percent complete: 0.6%; Average loss: 7.5114
# Iteration: 26; Percent complete: 0.7%; Average loss: 7.5282
# Iteration: 27; Percent complete: 0.7%; Average loss: 7.4340
# Iteration: 28; Percent complete: 0.7%; Average loss: 7.3973
# Iteration: 29; Percent complete: 0.7%; Average loss: 7.4247
# Iteration: 30; Percent complete: 0.8%; Average loss: 7.3526
# Iteration: 31; Percent complete: 0.8%; Average loss: 7.2073
# Iteration: 32; Percent complete: 0.8%; Average loss: 7.3248
# Iteration: 33; Percent complete: 0.8%; Average loss: 7.5413
# Iteration: 34; Percent complete: 0.9%; Average loss: 7.3755
# Iteration: 35; Percent complete: 0.9%; Average loss: 7.1543
# Iteration: 36; Percent complete: 0.9%; Average loss: 7.1337
# Iteration: 37; Percent complete: 0.9%; Average loss: 6.7151
# Iteration: 38; Percent complete: 0.9%; Average loss: 7.0422
# Iteration: 39; Percent complete: 1.0%; Average loss: 7.1605
# Iteration: 40; Percent complete: 1.0%; Average loss: 7.1131
# Iteration: 41; Percent complete: 1.0%; Average loss: 6.9626
# Iteration: 42; Percent complete: 1.1%; Average loss: 6.8938
# Iteration: 43; Percent complete: 1.1%; Average loss: 7.1102
# Iteration: 44; Percent complete: 1.1%; Average loss: 6.9084
# Iteration: 45; Percent complete: 1.1%; Average loss: 6.9631
# Iteration: 46; Percent complete: 1.1%; Average loss: 6.7878
# Iteration: 47; Percent complete: 1.2%; Average loss: 6.9289
# Iteration: 48; Percent complete: 1.2%; Average loss: 6.7514
# Iteration: 49; Percent complete: 1.2%; Average loss: 6.8392
# Iteration: 50; Percent complete: 1.2%; Average loss: 6.7384
# Iteration: 51; Percent complete: 1.3%; Average loss: 6.5793
# Iteration: 52; Percent complete: 1.3%; Average loss: 6.8233
# Iteration: 53; Percent complete: 1.3%; Average loss: 6.6875
# Iteration: 54; Percent complete: 1.4%; Average loss: 6.7317
# Iteration: 55; Percent complete: 1.4%; Average loss: 6.6851
# Iteration: 56; Percent complete: 1.4%; Average loss: 6.4201
# Iteration: 57; Percent complete: 1.4%; Average loss: 6.8383
# Iteration: 58; Percent complete: 1.5%; Average loss: 6.1813
# Iteration: 59; Percent complete: 1.5%; Average loss: 6.5998
# Iteration: 60; Percent complete: 1.5%; Average loss: 6.4789
# Iteration: 61; Percent complete: 1.5%; Average loss: 6.4216
# Iteration: 62; Percent complete: 1.6%; Average loss: 6.6132
# Iteration: 63; Percent complete: 1.6%; Average loss: 6.0802
# Iteration: 64; Percent complete: 1.6%; Average loss: 6.2135
# Iteration: 65; Percent complete: 1.6%; Average loss: 6.2015
# Iteration: 66; Percent complete: 1.7%; Average loss: 6.1295
# Iteration: 67; Percent complete: 1.7%; Average loss: 6.1844
# Iteration: 68; Percent complete: 1.7%; Average loss: 6.0492
# Iteration: 69; Percent complete: 1.7%; Average loss: 6.1598
# Iteration: 70; Percent complete: 1.8%; Average loss: 6.1033
# Iteration: 71; Percent complete: 1.8%; Average loss: 6.0351
# Iteration: 72; Percent complete: 1.8%; Average loss: 5.9002
# Iteration: 73; Percent complete: 1.8%; Average loss: 5.8395
# Iteration: 74; Percent complete: 1.8%; Average loss: 5.9143
# Iteration: 75; Percent complete: 1.9%; Average loss: 6.2069
# Iteration: 76; Percent complete: 1.9%; Average loss: 5.9058
# Iteration: 77; Percent complete: 1.9%; Average loss: 5.8788
# Iteration: 78; Percent complete: 1.9%; Average loss: 5.3619
# Iteration: 79; Percent complete: 2.0%; Average loss: 6.2420
# Iteration: 80; Percent complete: 2.0%; Average loss: 6.0430
# Iteration: 81; Percent complete: 2.0%; Average loss: 5.5646
# Iteration: 82; Percent complete: 2.1%; Average loss: 5.9426
# Iteration: 83; Percent complete: 2.1%; Average loss: 5.9070
# Iteration: 84; Percent complete: 2.1%; Average loss: 5.9827
# Iteration: 85; Percent complete: 2.1%; Average loss: 6.0008
# Iteration: 86; Percent complete: 2.1%; Average loss: 5.8631
# Iteration: 87; Percent complete: 2.2%; Average loss: 5.5814
# Iteration: 88; Percent complete: 2.2%; Average loss: 5.9050
# Iteration: 89; Percent complete: 2.2%; Average loss: 5.6327
# Iteration: 90; Percent complete: 2.2%; Average loss: 5.7480
# Iteration: 91; Percent complete: 2.3%; Average loss: 5.6660
# Iteration: 92; Percent complete: 2.3%; Average loss: 5.6646
# Iteration: 93; Percent complete: 2.3%; Average loss: 5.6584
# Iteration: 94; Percent complete: 2.4%; Average loss: 5.2685
# Iteration: 95; Percent complete: 2.4%; Average loss: 5.3637
# Iteration: 96; Percent complete: 2.4%; Average loss: 4.9934
# Iteration: 97; Percent complete: 2.4%; Average loss: 5.6024
# Iteration: 98; Percent complete: 2.5%; Average loss: 5.5365
# Iteration: 99; Percent complete: 2.5%; Average loss: 5.4917
# Iteration: 100; Percent complete: 2.5%; Average loss: 5.1878
# Iteration: 101; Percent complete: 2.5%; Average loss: 5.2915
# Iteration: 102; Percent complete: 2.5%; Average loss: 5.6883
# Iteration: 103; Percent complete: 2.6%; Average loss: 5.3171
# Iteration: 104; Percent complete: 2.6%; Average loss: 5.6205
# Iteration: 105; Percent complete: 2.6%; Average loss: 4.9938
# Iteration: 106; Percent complete: 2.6%; Average loss: 5.2398
# Iteration: 107; Percent complete: 2.7%; Average loss: 5.2520
# Iteration: 108; Percent complete: 2.7%; Average loss: 5.3817
# Iteration: 109; Percent complete: 2.7%; Average loss: 5.2635
# Iteration: 110; Percent complete: 2.8%; Average loss: 5.3032
# Iteration: 111; Percent complete: 2.8%; Average loss: 5.1970
# Iteration: 112; Percent complete: 2.8%; Average loss: 5.0533
# Iteration: 113; Percent complete: 2.8%; Average loss: 5.1400
# Iteration: 114; Percent complete: 2.9%; Average loss: 5.3046
# Iteration: 115; Percent complete: 2.9%; Average loss: 5.2196
# Iteration: 116; Percent complete: 2.9%; Average loss: 5.2334
# Iteration: 117; Percent complete: 2.9%; Average loss: 4.9549
# Iteration: 118; Percent complete: 2.9%; Average loss: 4.9968
# Iteration: 119; Percent complete: 3.0%; Average loss: 5.1494
# Iteration: 120; Percent complete: 3.0%; Average loss: 5.2648
# Iteration: 121; Percent complete: 3.0%; Average loss: 5.1528
# Iteration: 122; Percent complete: 3.0%; Average loss: 5.0350
# Iteration: 123; Percent complete: 3.1%; Average loss: 5.0715
# Iteration: 124; Percent complete: 3.1%; Average loss: 4.9552
# Iteration: 125; Percent complete: 3.1%; Average loss: 4.5565
# Iteration: 126; Percent complete: 3.1%; Average loss: 5.2162
# Iteration: 127; Percent complete: 3.2%; Average loss: 5.1786
# Iteration: 128; Percent complete: 3.2%; Average loss: 5.0408
# Iteration: 129; Percent complete: 3.2%; Average loss: 4.7354
# Iteration: 130; Percent complete: 3.2%; Average loss: 4.9448
# Iteration: 131; Percent complete: 3.3%; Average loss: 4.7553
# Iteration: 132; Percent complete: 3.3%; Average loss: 4.7874
# Iteration: 133; Percent complete: 3.3%; Average loss: 4.7153
# Iteration: 134; Percent complete: 3.4%; Average loss: 4.2888
# Iteration: 135; Percent complete: 3.4%; Average loss: 4.9002
# Iteration: 136; Percent complete: 3.4%; Average loss: 5.3769
# Iteration: 137; Percent complete: 3.4%; Average loss: 4.8364
# Iteration: 138; Percent complete: 3.5%; Average loss: 5.2101
# Iteration: 139; Percent complete: 3.5%; Average loss: 5.0655
# Iteration: 140; Percent complete: 3.5%; Average loss: 4.7721
# Iteration: 141; Percent complete: 3.5%; Average loss: 4.6029
# Iteration: 142; Percent complete: 3.5%; Average loss: 4.2891
# Iteration: 143; Percent complete: 3.6%; Average loss: 4.5613
# Iteration: 144; Percent complete: 3.6%; Average loss: 5.0376
# Iteration: 145; Percent complete: 3.6%; Average loss: 4.6249
# Iteration: 146; Percent complete: 3.6%; Average loss: 4.9215
# Iteration: 147; Percent complete: 3.7%; Average loss: 4.7388
# Iteration: 148; Percent complete: 3.7%; Average loss: 4.9122
# Iteration: 149; Percent complete: 3.7%; Average loss: 4.7892
# Iteration: 150; Percent complete: 3.8%; Average loss: 4.9334
# Iteration: 151; Percent complete: 3.8%; Average loss: 4.7275
# Iteration: 152; Percent complete: 3.8%; Average loss: 4.8481
# Iteration: 153; Percent complete: 3.8%; Average loss: 4.7879
# Iteration: 154; Percent complete: 3.9%; Average loss: 5.1098
# Iteration: 155; Percent complete: 3.9%; Average loss: 4.5721
# Iteration: 156; Percent complete: 3.9%; Average loss: 4.8757
# Iteration: 157; Percent complete: 3.9%; Average loss: 3.9159
# Iteration: 158; Percent complete: 4.0%; Average loss: 4.8204
# Iteration: 159; Percent complete: 4.0%; Average loss: 4.8075
# Iteration: 160; Percent complete: 4.0%; Average loss: 4.9106
# Iteration: 161; Percent complete: 4.0%; Average loss: 4.5190
# Iteration: 162; Percent complete: 4.0%; Average loss: 5.0217
# Iteration: 163; Percent complete: 4.1%; Average loss: 4.4868
# Iteration: 164; Percent complete: 4.1%; Average loss: 4.4949
# Iteration: 165; Percent complete: 4.1%; Average loss: 4.2667
# Iteration: 166; Percent complete: 4.2%; Average loss: 4.6430
# Iteration: 167; Percent complete: 4.2%; Average loss: 4.7759
# Iteration: 168; Percent complete: 4.2%; Average loss: 4.5048
# Iteration: 169; Percent complete: 4.2%; Average loss: 4.8285
# Iteration: 170; Percent complete: 4.2%; Average loss: 4.6940
# Iteration: 171; Percent complete: 4.3%; Average loss: 4.7473
# Iteration: 172; Percent complete: 4.3%; Average loss: 4.2706
# Iteration: 173; Percent complete: 4.3%; Average loss: 4.8398
# Iteration: 174; Percent complete: 4.3%; Average loss: 4.5317
# Iteration: 175; Percent complete: 4.4%; Average loss: 3.8014
# Iteration: 176; Percent complete: 4.4%; Average loss: 4.5921
# Iteration: 177; Percent complete: 4.4%; Average loss: 4.7365
# Iteration: 178; Percent complete: 4.5%; Average loss: 4.8385
# Iteration: 179; Percent complete: 4.5%; Average loss: 4.1310
# Iteration: 180; Percent complete: 4.5%; Average loss: 4.4608
# Iteration: 181; Percent complete: 4.5%; Average loss: 4.5261
# Iteration: 182; Percent complete: 4.5%; Average loss: 4.1228
# Iteration: 183; Percent complete: 4.6%; Average loss: 4.2390
# Iteration: 184; Percent complete: 4.6%; Average loss: 4.0952
# Iteration: 185; Percent complete: 4.6%; Average loss: 4.0168
# Iteration: 186; Percent complete: 4.7%; Average loss: 4.4062
# Iteration: 187; Percent complete: 4.7%; Average loss: 4.6050
# Iteration: 188; Percent complete: 4.7%; Average loss: 4.2320
# Iteration: 189; Percent complete: 4.7%; Average loss: 4.7241
# Iteration: 190; Percent complete: 4.8%; Average loss: 4.3305
# Iteration: 191; Percent complete: 4.8%; Average loss: 5.0440
# Iteration: 192; Percent complete: 4.8%; Average loss: 3.6560
# Iteration: 193; Percent complete: 4.8%; Average loss: 4.1252
# Iteration: 194; Percent complete: 4.9%; Average loss: 4.6860
# Iteration: 195; Percent complete: 4.9%; Average loss: 4.5219
# Iteration: 196; Percent complete: 4.9%; Average loss: 4.2353
# Iteration: 197; Percent complete: 4.9%; Average loss: 4.4117
# Iteration: 198; Percent complete: 5.0%; Average loss: 4.7711
# Iteration: 199; Percent complete: 5.0%; Average loss: 4.5868
# Iteration: 200; Percent complete: 5.0%; Average loss: 4.5485
# Iteration: 201; Percent complete: 5.0%; Average loss: 4.6487
# Iteration: 202; Percent complete: 5.1%; Average loss: 4.1941
# Iteration: 203; Percent complete: 5.1%; Average loss: 4.6681
# Iteration: 204; Percent complete: 5.1%; Average loss: 4.2339
# Iteration: 205; Percent complete: 5.1%; Average loss: 4.5636
# Iteration: 206; Percent complete: 5.1%; Average loss: 4.7370
# Iteration: 207; Percent complete: 5.2%; Average loss: 4.4419
# Iteration: 208; Percent complete: 5.2%; Average loss: 4.7112
# Iteration: 209; Percent complete: 5.2%; Average loss: 4.4215
# Iteration: 210; Percent complete: 5.2%; Average loss: 4.2663
# Iteration: 211; Percent complete: 5.3%; Average loss: 4.5614
# Iteration: 212; Percent complete: 5.3%; Average loss: 4.1152
# Iteration: 213; Percent complete: 5.3%; Average loss: 4.3666
# Iteration: 214; Percent complete: 5.3%; Average loss: 4.8271
# Iteration: 215; Percent complete: 5.4%; Average loss: 4.0252
# Iteration: 216; Percent complete: 5.4%; Average loss: 3.8684
# Iteration: 217; Percent complete: 5.4%; Average loss: 4.5437
# Iteration: 218; Percent complete: 5.5%; Average loss: 4.4354
# Iteration: 219; Percent complete: 5.5%; Average loss: 3.8316
# Iteration: 220; Percent complete: 5.5%; Average loss: 4.2658
# Iteration: 221; Percent complete: 5.5%; Average loss: 3.9236
# Iteration: 222; Percent complete: 5.5%; Average loss: 4.2310
# Iteration: 223; Percent complete: 5.6%; Average loss: 4.5906
# Iteration: 224; Percent complete: 5.6%; Average loss: 3.7898
# Iteration: 225; Percent complete: 5.6%; Average loss: 4.0633
# Iteration: 226; Percent complete: 5.7%; Average loss: 4.8980
# Iteration: 227; Percent complete: 5.7%; Average loss: 4.2418
# Iteration: 228; Percent complete: 5.7%; Average loss: 4.8382
# Iteration: 229; Percent complete: 5.7%; Average loss: 4.5719
# Iteration: 230; Percent complete: 5.8%; Average loss: 4.5734
# Iteration: 231; Percent complete: 5.8%; Average loss: 4.4391
# Iteration: 232; Percent complete: 5.8%; Average loss: 4.3203
# Iteration: 233; Percent complete: 5.8%; Average loss: 4.2030
# Iteration: 234; Percent complete: 5.9%; Average loss: 4.4900
# Iteration: 235; Percent complete: 5.9%; Average loss: 4.6708
# Iteration: 236; Percent complete: 5.9%; Average loss: 4.1292
# Iteration: 237; Percent complete: 5.9%; Average loss: 4.2572
# Iteration: 238; Percent complete: 5.9%; Average loss: 4.6706
# Iteration: 239; Percent complete: 6.0%; Average loss: 4.2991
# Iteration: 240; Percent complete: 6.0%; Average loss: 4.1864
# Iteration: 241; Percent complete: 6.0%; Average loss: 4.4382
# Iteration: 242; Percent complete: 6.0%; Average loss: 4.0061
# Iteration: 243; Percent complete: 6.1%; Average loss: 4.8285
# Iteration: 244; Percent complete: 6.1%; Average loss: 4.0090
# Iteration: 245; Percent complete: 6.1%; Average loss: 4.5483
# Iteration: 246; Percent complete: 6.2%; Average loss: 3.9743
# Iteration: 247; Percent complete: 6.2%; Average loss: 4.5230
# Iteration: 248; Percent complete: 6.2%; Average loss: 4.4903
# Iteration: 249; Percent complete: 6.2%; Average loss: 3.9334
# Iteration: 250; Percent complete: 6.2%; Average loss: 4.4171
# Iteration: 251; Percent complete: 6.3%; Average loss: 4.7435
# Iteration: 252; Percent complete: 6.3%; Average loss: 4.8125
# Iteration: 253; Percent complete: 6.3%; Average loss: 4.3425
# Iteration: 254; Percent complete: 6.3%; Average loss: 4.4472
# Iteration: 255; Percent complete: 6.4%; Average loss: 4.0752
# Iteration: 256; Percent complete: 6.4%; Average loss: 4.2730
# Iteration: 257; Percent complete: 6.4%; Average loss: 4.7107
# Iteration: 258; Percent complete: 6.5%; Average loss: 4.2460
# Iteration: 259; Percent complete: 6.5%; Average loss: 4.7142
# Iteration: 260; Percent complete: 6.5%; Average loss: 4.1949
# Iteration: 261; Percent complete: 6.5%; Average loss: 4.5251
# Iteration: 262; Percent complete: 6.6%; Average loss: 4.5731
# Iteration: 263; Percent complete: 6.6%; Average loss: 4.5273
# Iteration: 264; Percent complete: 6.6%; Average loss: 4.3272
# Iteration: 265; Percent complete: 6.6%; Average loss: 4.9315
# Iteration: 266; Percent complete: 6.7%; Average loss: 4.3964
# Iteration: 267; Percent complete: 6.7%; Average loss: 3.9288
# Iteration: 268; Percent complete: 6.7%; Average loss: 4.5478
# Iteration: 269; Percent complete: 6.7%; Average loss: 4.5714
# Iteration: 270; Percent complete: 6.8%; Average loss: 4.8807
# Iteration: 271; Percent complete: 6.8%; Average loss: 4.3780
# Iteration: 272; Percent complete: 6.8%; Average loss: 4.8534
# Iteration: 273; Percent complete: 6.8%; Average loss: 3.8694
# Iteration: 274; Percent complete: 6.9%; Average loss: 4.6730
# Iteration: 275; Percent complete: 6.9%; Average loss: 4.1074
# Iteration: 276; Percent complete: 6.9%; Average loss: 4.1304
# Iteration: 277; Percent complete: 6.9%; Average loss: 4.6935
# Iteration: 278; Percent complete: 7.0%; Average loss: 3.8857
# Iteration: 279; Percent complete: 7.0%; Average loss: 4.1131
# Iteration: 280; Percent complete: 7.0%; Average loss: 4.5366
# Iteration: 281; Percent complete: 7.0%; Average loss: 4.4795
# Iteration: 282; Percent complete: 7.0%; Average loss: 4.5508
# Iteration: 283; Percent complete: 7.1%; Average loss: 4.6279
# Iteration: 284; Percent complete: 7.1%; Average loss: 4.5105
# Iteration: 285; Percent complete: 7.1%; Average loss: 3.6228
# Iteration: 286; Percent complete: 7.1%; Average loss: 4.1681
# Iteration: 287; Percent complete: 7.2%; Average loss: 4.2950
# Iteration: 288; Percent complete: 7.2%; Average loss: 4.3877
# Iteration: 289; Percent complete: 7.2%; Average loss: 4.2279
# Iteration: 290; Percent complete: 7.2%; Average loss: 4.4005
# Iteration: 291; Percent complete: 7.3%; Average loss: 4.4913
# Iteration: 292; Percent complete: 7.3%; Average loss: 4.5409
# Iteration: 293; Percent complete: 7.3%; Average loss: 3.6971
# Iteration: 294; Percent complete: 7.3%; Average loss: 4.1045
# Iteration: 295; Percent complete: 7.4%; Average loss: 4.5122
# Iteration: 296; Percent complete: 7.4%; Average loss: 4.3149
# Iteration: 297; Percent complete: 7.4%; Average loss: 4.3236
# Iteration: 298; Percent complete: 7.4%; Average loss: 3.9250
# Iteration: 299; Percent complete: 7.5%; Average loss: 3.9316
# Iteration: 300; Percent complete: 7.5%; Average loss: 4.1752
# Iteration: 301; Percent complete: 7.5%; Average loss: 4.4848
# Iteration: 302; Percent complete: 7.5%; Average loss: 3.9488
# Iteration: 303; Percent complete: 7.6%; Average loss: 3.9769
# Iteration: 304; Percent complete: 7.6%; Average loss: 4.4554
# Iteration: 305; Percent complete: 7.6%; Average loss: 4.1100
# Iteration: 306; Percent complete: 7.6%; Average loss: 4.8829
# Iteration: 307; Percent complete: 7.7%; Average loss: 4.2487
# Iteration: 308; Percent complete: 7.7%; Average loss: 4.8407
# Iteration: 309; Percent complete: 7.7%; Average loss: 3.9973
# Iteration: 310; Percent complete: 7.8%; Average loss: 4.2014
# Iteration: 311; Percent complete: 7.8%; Average loss: 4.1415
# Iteration: 312; Percent complete: 7.8%; Average loss: 4.2013
# Iteration: 313; Percent complete: 7.8%; Average loss: 4.3878
# Iteration: 314; Percent complete: 7.8%; Average loss: 4.4043
# Iteration: 315; Percent complete: 7.9%; Average loss: 4.2535
# Iteration: 316; Percent complete: 7.9%; Average loss: 4.2751
# Iteration: 317; Percent complete: 7.9%; Average loss: 4.5138
# Iteration: 318; Percent complete: 8.0%; Average loss: 3.9985
# Iteration: 319; Percent complete: 8.0%; Average loss: 4.1601
# Iteration: 320; Percent complete: 8.0%; Average loss: 3.8712
# Iteration: 321; Percent complete: 8.0%; Average loss: 4.4144
# Iteration: 322; Percent complete: 8.1%; Average loss: 4.0189
# Iteration: 323; Percent complete: 8.1%; Average loss: 4.5772
# Iteration: 324; Percent complete: 8.1%; Average loss: 4.3802
# Iteration: 325; Percent complete: 8.1%; Average loss: 4.2179
# Iteration: 326; Percent complete: 8.2%; Average loss: 4.3188
# Iteration: 327; Percent complete: 8.2%; Average loss: 4.5650
# Iteration: 328; Percent complete: 8.2%; Average loss: 5.1030
# Iteration: 329; Percent complete: 8.2%; Average loss: 3.6691
# Iteration: 330; Percent complete: 8.2%; Average loss: 4.3722
# Iteration: 331; Percent complete: 8.3%; Average loss: 4.5052
# Iteration: 332; Percent complete: 8.3%; Average loss: 4.1770
# Iteration: 333; Percent complete: 8.3%; Average loss: 4.0257
# Iteration: 334; Percent complete: 8.3%; Average loss: 4.3706
# Iteration: 335; Percent complete: 8.4%; Average loss: 4.7066
# Iteration: 336; Percent complete: 8.4%; Average loss: 4.2422
# Iteration: 337; Percent complete: 8.4%; Average loss: 4.5607
# Iteration: 338; Percent complete: 8.5%; Average loss: 4.6431
# Iteration: 339; Percent complete: 8.5%; Average loss: 4.3815
# Iteration: 340; Percent complete: 8.5%; Average loss: 4.0288
# Iteration: 341; Percent complete: 8.5%; Average loss: 4.6113
# Iteration: 342; Percent complete: 8.6%; Average loss: 4.1395
# Iteration: 343; Percent complete: 8.6%; Average loss: 3.7477
# Iteration: 344; Percent complete: 8.6%; Average loss: 4.4098
# Iteration: 345; Percent complete: 8.6%; Average loss: 4.6885
# Iteration: 346; Percent complete: 8.6%; Average loss: 4.5100
# Iteration: 347; Percent complete: 8.7%; Average loss: 4.0452
# Iteration: 348; Percent complete: 8.7%; Average loss: 3.9132
# Iteration: 349; Percent complete: 8.7%; Average loss: 3.7284
# Iteration: 350; Percent complete: 8.8%; Average loss: 4.2137
# Iteration: 351; Percent complete: 8.8%; Average loss: 3.9657
# Iteration: 352; Percent complete: 8.8%; Average loss: 4.5056
# Iteration: 353; Percent complete: 8.8%; Average loss: 3.6685
# Iteration: 354; Percent complete: 8.8%; Average loss: 3.7453
# Iteration: 355; Percent complete: 8.9%; Average loss: 3.9378
# Iteration: 356; Percent complete: 8.9%; Average loss: 3.7572
# Iteration: 357; Percent complete: 8.9%; Average loss: 4.2343
# Iteration: 358; Percent complete: 8.9%; Average loss: 4.0653
# Iteration: 359; Percent complete: 9.0%; Average loss: 4.7727
# Iteration: 360; Percent complete: 9.0%; Average loss: 4.3980
# Iteration: 361; Percent complete: 9.0%; Average loss: 4.4752
# Iteration: 362; Percent complete: 9.0%; Average loss: 4.2782
# Iteration: 363; Percent complete: 9.1%; Average loss: 4.1789
# Iteration: 364; Percent complete: 9.1%; Average loss: 4.0379
# Iteration: 365; Percent complete: 9.1%; Average loss: 4.7455
# Iteration: 366; Percent complete: 9.2%; Average loss: 4.5578
# Iteration: 367; Percent complete: 9.2%; Average loss: 3.8344
# Iteration: 368; Percent complete: 9.2%; Average loss: 4.5016
# Iteration: 369; Percent complete: 9.2%; Average loss: 4.6186
# Iteration: 370; Percent complete: 9.2%; Average loss: 4.6372
# Iteration: 371; Percent complete: 9.3%; Average loss: 4.4751
# Iteration: 372; Percent complete: 9.3%; Average loss: 4.2066
# Iteration: 373; Percent complete: 9.3%; Average loss: 3.8127
# Iteration: 374; Percent complete: 9.3%; Average loss: 4.4936
# Iteration: 375; Percent complete: 9.4%; Average loss: 4.1153
# Iteration: 376; Percent complete: 9.4%; Average loss: 4.0120
# Iteration: 377; Percent complete: 9.4%; Average loss: 4.0646
# Iteration: 378; Percent complete: 9.4%; Average loss: 4.5083
# Iteration: 379; Percent complete: 9.5%; Average loss: 3.9382
# Iteration: 380; Percent complete: 9.5%; Average loss: 4.4191
# Iteration: 381; Percent complete: 9.5%; Average loss: 4.1561
# Iteration: 382; Percent complete: 9.6%; Average loss: 3.9905
# Iteration: 383; Percent complete: 9.6%; Average loss: 4.3501
# Iteration: 384; Percent complete: 9.6%; Average loss: 4.3459
# Iteration: 385; Percent complete: 9.6%; Average loss: 4.4322
# Iteration: 386; Percent complete: 9.7%; Average loss: 4.4268
# Iteration: 387; Percent complete: 9.7%; Average loss: 4.3360
# Iteration: 388; Percent complete: 9.7%; Average loss: 4.4743
# Iteration: 389; Percent complete: 9.7%; Average loss: 4.2125
# Iteration: 390; Percent complete: 9.8%; Average loss: 4.1526
# Iteration: 391; Percent complete: 9.8%; Average loss: 4.1841
# Iteration: 392; Percent complete: 9.8%; Average loss: 3.9427
# Iteration: 393; Percent complete: 9.8%; Average loss: 4.2122
# Iteration: 394; Percent complete: 9.8%; Average loss: 4.0525
# Iteration: 395; Percent complete: 9.9%; Average loss: 4.2448
# Iteration: 396; Percent complete: 9.9%; Average loss: 4.3122
# Iteration: 397; Percent complete: 9.9%; Average loss: 4.4329
# Iteration: 398; Percent complete: 10.0%; Average loss: 4.4812
# Iteration: 399; Percent complete: 10.0%; Average loss: 4.6075
# Iteration: 400; Percent complete: 10.0%; Average loss: 4.5918
# Iteration: 401; Percent complete: 10.0%; Average loss: 3.7109
# Iteration: 402; Percent complete: 10.1%; Average loss: 4.4090
# Iteration: 403; Percent complete: 10.1%; Average loss: 4.5188
# Iteration: 404; Percent complete: 10.1%; Average loss: 4.4887
# Iteration: 405; Percent complete: 10.1%; Average loss: 4.5589
# Iteration: 406; Percent complete: 10.2%; Average loss: 4.0015
# Iteration: 407; Percent complete: 10.2%; Average loss: 4.5683
# Iteration: 408; Percent complete: 10.2%; Average loss: 3.7910
# Iteration: 409; Percent complete: 10.2%; Average loss: 4.6847
# Iteration: 410; Percent complete: 10.2%; Average loss: 4.1289
# Iteration: 411; Percent complete: 10.3%; Average loss: 4.3808
# Iteration: 412; Percent complete: 10.3%; Average loss: 3.8481
# Iteration: 413; Percent complete: 10.3%; Average loss: 4.6575
# Iteration: 414; Percent complete: 10.3%; Average loss: 4.4477
# Iteration: 415; Percent complete: 10.4%; Average loss: 4.2694
# Iteration: 416; Percent complete: 10.4%; Average loss: 4.0966
# Iteration: 417; Percent complete: 10.4%; Average loss: 4.2942
# Iteration: 418; Percent complete: 10.4%; Average loss: 4.2250
# Iteration: 419; Percent complete: 10.5%; Average loss: 3.8879
# Iteration: 420; Percent complete: 10.5%; Average loss: 3.7373
# Iteration: 421; Percent complete: 10.5%; Average loss: 4.5174
# Iteration: 422; Percent complete: 10.5%; Average loss: 4.1832
# Iteration: 423; Percent complete: 10.6%; Average loss: 4.1013
# Iteration: 424; Percent complete: 10.6%; Average loss: 3.7197
# Iteration: 425; Percent complete: 10.6%; Average loss: 4.3549
# Iteration: 426; Percent complete: 10.7%; Average loss: 3.8208
# Iteration: 427; Percent complete: 10.7%; Average loss: 4.1901
# Iteration: 428; Percent complete: 10.7%; Average loss: 4.0890
# Iteration: 429; Percent complete: 10.7%; Average loss: 4.4480
# Iteration: 430; Percent complete: 10.8%; Average loss: 4.2928
# Iteration: 431; Percent complete: 10.8%; Average loss: 4.6105
# Iteration: 432; Percent complete: 10.8%; Average loss: 4.1773
# Iteration: 433; Percent complete: 10.8%; Average loss: 4.7924
# Iteration: 434; Percent complete: 10.8%; Average loss: 4.0237
# Iteration: 435; Percent complete: 10.9%; Average loss: 4.0948
# Iteration: 436; Percent complete: 10.9%; Average loss: 3.9839
# Iteration: 437; Percent complete: 10.9%; Average loss: 3.9162
# Iteration: 438; Percent complete: 10.9%; Average loss: 4.0630
# Iteration: 439; Percent complete: 11.0%; Average loss: 4.1917
# Iteration: 440; Percent complete: 11.0%; Average loss: 4.3237
# Iteration: 441; Percent complete: 11.0%; Average loss: 4.2572
# Iteration: 442; Percent complete: 11.1%; Average loss: 4.5831
# Iteration: 443; Percent complete: 11.1%; Average loss: 4.6369
# Iteration: 444; Percent complete: 11.1%; Average loss: 4.2279
# Iteration: 445; Percent complete: 11.1%; Average loss: 4.0122
# Iteration: 446; Percent complete: 11.2%; Average loss: 4.3813
# Iteration: 447; Percent complete: 11.2%; Average loss: 4.0966
# Iteration: 448; Percent complete: 11.2%; Average loss: 3.8203
# Iteration: 449; Percent complete: 11.2%; Average loss: 3.9986
# Iteration: 450; Percent complete: 11.2%; Average loss: 3.2659
# Iteration: 451; Percent complete: 11.3%; Average loss: 3.6629
# Iteration: 452; Percent complete: 11.3%; Average loss: 3.9889
# Iteration: 453; Percent complete: 11.3%; Average loss: 4.0078
# Iteration: 454; Percent complete: 11.3%; Average loss: 3.7671
# Iteration: 455; Percent complete: 11.4%; Average loss: 4.1485
# Iteration: 456; Percent complete: 11.4%; Average loss: 4.3506
# Iteration: 457; Percent complete: 11.4%; Average loss: 4.3723
# Iteration: 458; Percent complete: 11.5%; Average loss: 4.2727
# Iteration: 459; Percent complete: 11.5%; Average loss: 4.0966
# Iteration: 460; Percent complete: 11.5%; Average loss: 4.1763
# Iteration: 461; Percent complete: 11.5%; Average loss: 4.1965
# Iteration: 462; Percent complete: 11.6%; Average loss: 4.2383
# Iteration: 463; Percent complete: 11.6%; Average loss: 4.0020
# Iteration: 464; Percent complete: 11.6%; Average loss: 3.7462
# Iteration: 465; Percent complete: 11.6%; Average loss: 3.7815
# Iteration: 466; Percent complete: 11.7%; Average loss: 3.5324
# Iteration: 467; Percent complete: 11.7%; Average loss: 4.5897
# Iteration: 468; Percent complete: 11.7%; Average loss: 3.9656
# Iteration: 469; Percent complete: 11.7%; Average loss: 3.9822
# Iteration: 470; Percent complete: 11.8%; Average loss: 4.0424
# Iteration: 471; Percent complete: 11.8%; Average loss: 3.7410
# Iteration: 472; Percent complete: 11.8%; Average loss: 4.1929
# Iteration: 473; Percent complete: 11.8%; Average loss: 3.9740
# Iteration: 474; Percent complete: 11.8%; Average loss: 4.6342
# Iteration: 475; Percent complete: 11.9%; Average loss: 4.1915
# Iteration: 476; Percent complete: 11.9%; Average loss: 4.3110
# Iteration: 477; Percent complete: 11.9%; Average loss: 3.8640
# Iteration: 478; Percent complete: 11.9%; Average loss: 3.4550
# Iteration: 479; Percent complete: 12.0%; Average loss: 4.5511
# Iteration: 480; Percent complete: 12.0%; Average loss: 3.3719
# Iteration: 481; Percent complete: 12.0%; Average loss: 4.2598
# Iteration: 482; Percent complete: 12.0%; Average loss: 4.0842
# Iteration: 483; Percent complete: 12.1%; Average loss: 3.7993
# Iteration: 484; Percent complete: 12.1%; Average loss: 4.4043
# Iteration: 485; Percent complete: 12.1%; Average loss: 4.1707
# Iteration: 486; Percent complete: 12.2%; Average loss: 4.1079
# Iteration: 487; Percent complete: 12.2%; Average loss: 4.0332
# Iteration: 488; Percent complete: 12.2%; Average loss: 4.0727
# Iteration: 489; Percent complete: 12.2%; Average loss: 3.5544
# Iteration: 490; Percent complete: 12.2%; Average loss: 3.8812
# Iteration: 491; Percent complete: 12.3%; Average loss: 4.0923
# Iteration: 492; Percent complete: 12.3%; Average loss: 3.9923
# Iteration: 493; Percent complete: 12.3%; Average loss: 3.4489
# Iteration: 494; Percent complete: 12.3%; Average loss: 3.7789
# Iteration: 495; Percent complete: 12.4%; Average loss: 4.0934
# Iteration: 496; Percent complete: 12.4%; Average loss: 4.0014
# Iteration: 497; Percent complete: 12.4%; Average loss: 4.4744
# Iteration: 498; Percent complete: 12.4%; Average loss: 4.4676
# Iteration: 499; Percent complete: 12.5%; Average loss: 4.3734
# Iteration: 500; Percent complete: 12.5%; Average loss: 3.5724
# Iteration: 501; Percent complete: 12.5%; Average loss: 3.9640
# Iteration: 502; Percent complete: 12.6%; Average loss: 3.8518
# Iteration: 503; Percent complete: 12.6%; Average loss: 4.4865
# Iteration: 504; Percent complete: 12.6%; Average loss: 4.1370
# Iteration: 505; Percent complete: 12.6%; Average loss: 3.5812
# Iteration: 506; Percent complete: 12.7%; Average loss: 4.1835
# Iteration: 507; Percent complete: 12.7%; Average loss: 3.7812
# Iteration: 508; Percent complete: 12.7%; Average loss: 4.0947
# Iteration: 509; Percent complete: 12.7%; Average loss: 4.0186
# Iteration: 510; Percent complete: 12.8%; Average loss: 4.2350
# Iteration: 511; Percent complete: 12.8%; Average loss: 4.9063
# Iteration: 512; Percent complete: 12.8%; Average loss: 3.7932
# Iteration: 513; Percent complete: 12.8%; Average loss: 4.3402
# Iteration: 514; Percent complete: 12.8%; Average loss: 3.7263
# Iteration: 515; Percent complete: 12.9%; Average loss: 4.1332
# Iteration: 516; Percent complete: 12.9%; Average loss: 4.1974
# Iteration: 517; Percent complete: 12.9%; Average loss: 4.5345
# Iteration: 518; Percent complete: 13.0%; Average loss: 4.1265
# Iteration: 519; Percent complete: 13.0%; Average loss: 3.9108
# Iteration: 520; Percent complete: 13.0%; Average loss: 4.0995
# Iteration: 521; Percent complete: 13.0%; Average loss: 4.3854
# Iteration: 522; Percent complete: 13.1%; Average loss: 3.9533
# Iteration: 523; Percent complete: 13.1%; Average loss: 3.8913
# Iteration: 524; Percent complete: 13.1%; Average loss: 4.4233
# Iteration: 525; Percent complete: 13.1%; Average loss: 3.6035
# Iteration: 526; Percent complete: 13.2%; Average loss: 4.1563
# Iteration: 527; Percent complete: 13.2%; Average loss: 3.6725
# Iteration: 528; Percent complete: 13.2%; Average loss: 4.1053
# Iteration: 529; Percent complete: 13.2%; Average loss: 4.0283
# Iteration: 530; Percent complete: 13.2%; Average loss: 3.6738
# Iteration: 531; Percent complete: 13.3%; Average loss: 4.1585
# Iteration: 532; Percent complete: 13.3%; Average loss: 3.9110
# Iteration: 533; Percent complete: 13.3%; Average loss: 3.7634
# Iteration: 534; Percent complete: 13.4%; Average loss: 4.1810
# Iteration: 535; Percent complete: 13.4%; Average loss: 4.2711
# Iteration: 536; Percent complete: 13.4%; Average loss: 3.6077
# Iteration: 537; Percent complete: 13.4%; Average loss: 4.0578
# Iteration: 538; Percent complete: 13.5%; Average loss: 3.6223
# Iteration: 539; Percent complete: 13.5%; Average loss: 3.9169
# Iteration: 540; Percent complete: 13.5%; Average loss: 4.1000
# Iteration: 541; Percent complete: 13.5%; Average loss: 3.7492
# Iteration: 542; Percent complete: 13.6%; Average loss: 4.2329
# Iteration: 543; Percent complete: 13.6%; Average loss: 3.7935
# Iteration: 544; Percent complete: 13.6%; Average loss: 3.4671
# Iteration: 545; Percent complete: 13.6%; Average loss: 4.0761
# Iteration: 546; Percent complete: 13.7%; Average loss: 4.0228
# Iteration: 547; Percent complete: 13.7%; Average loss: 4.1255
# Iteration: 548; Percent complete: 13.7%; Average loss: 4.4276
# Iteration: 549; Percent complete: 13.7%; Average loss: 3.9544
# Iteration: 550; Percent complete: 13.8%; Average loss: 4.2458
# Iteration: 551; Percent complete: 13.8%; Average loss: 3.6327
# Iteration: 552; Percent complete: 13.8%; Average loss: 4.1617
# Iteration: 553; Percent complete: 13.8%; Average loss: 3.8975
# Iteration: 554; Percent complete: 13.9%; Average loss: 4.4277
# Iteration: 555; Percent complete: 13.9%; Average loss: 3.7941
# Iteration: 556; Percent complete: 13.9%; Average loss: 4.7904
# Iteration: 557; Percent complete: 13.9%; Average loss: 3.8813
# Iteration: 558; Percent complete: 14.0%; Average loss: 3.8998
# Iteration: 559; Percent complete: 14.0%; Average loss: 4.2012
# Iteration: 560; Percent complete: 14.0%; Average loss: 4.3024
# Iteration: 561; Percent complete: 14.0%; Average loss: 4.1225
# Iteration: 562; Percent complete: 14.1%; Average loss: 4.0489
# Iteration: 563; Percent complete: 14.1%; Average loss: 4.6714
# Iteration: 564; Percent complete: 14.1%; Average loss: 4.4984
# Iteration: 565; Percent complete: 14.1%; Average loss: 3.9783
# Iteration: 566; Percent complete: 14.1%; Average loss: 4.2323
# Iteration: 567; Percent complete: 14.2%; Average loss: 3.3828
# Iteration: 568; Percent complete: 14.2%; Average loss: 4.3554
# Iteration: 569; Percent complete: 14.2%; Average loss: 4.2054
# Iteration: 570; Percent complete: 14.2%; Average loss: 3.7309
# Iteration: 571; Percent complete: 14.3%; Average loss: 3.8540
# Iteration: 572; Percent complete: 14.3%; Average loss: 3.7131
# Iteration: 573; Percent complete: 14.3%; Average loss: 4.3322
# Iteration: 574; Percent complete: 14.3%; Average loss: 4.2792
# Iteration: 575; Percent complete: 14.4%; Average loss: 4.3899
# Iteration: 576; Percent complete: 14.4%; Average loss: 3.4967
# Iteration: 577; Percent complete: 14.4%; Average loss: 4.6694
# Iteration: 578; Percent complete: 14.4%; Average loss: 3.7773
# Iteration: 579; Percent complete: 14.5%; Average loss: 3.9403
# Iteration: 580; Percent complete: 14.5%; Average loss: 4.1622
# Iteration: 581; Percent complete: 14.5%; Average loss: 4.2271
# Iteration: 582; Percent complete: 14.5%; Average loss: 3.7919
# Iteration: 583; Percent complete: 14.6%; Average loss: 3.5827
# Iteration: 584; Percent complete: 14.6%; Average loss: 4.3739
# Iteration: 585; Percent complete: 14.6%; Average loss: 3.8986
# Iteration: 586; Percent complete: 14.6%; Average loss: 4.3684
# Iteration: 587; Percent complete: 14.7%; Average loss: 3.9200
# Iteration: 588; Percent complete: 14.7%; Average loss: 3.8236
# Iteration: 589; Percent complete: 14.7%; Average loss: 3.9711
# Iteration: 590; Percent complete: 14.8%; Average loss: 4.3093
# Iteration: 591; Percent complete: 14.8%; Average loss: 3.9288
# Iteration: 592; Percent complete: 14.8%; Average loss: 4.4661
# Iteration: 593; Percent complete: 14.8%; Average loss: 4.0675
# Iteration: 594; Percent complete: 14.8%; Average loss: 3.6468
# Iteration: 595; Percent complete: 14.9%; Average loss: 4.1582
# Iteration: 596; Percent complete: 14.9%; Average loss: 3.9575
# Iteration: 597; Percent complete: 14.9%; Average loss: 4.2623
# Iteration: 598; Percent complete: 14.9%; Average loss: 3.2879
# Iteration: 599; Percent complete: 15.0%; Average loss: 4.5891
# Iteration: 600; Percent complete: 15.0%; Average loss: 3.9839
# Iteration: 601; Percent complete: 15.0%; Average loss: 3.8618
# Iteration: 602; Percent complete: 15.0%; Average loss: 3.9751
# Iteration: 603; Percent complete: 15.1%; Average loss: 3.6101
# Iteration: 604; Percent complete: 15.1%; Average loss: 4.1081
# Iteration: 605; Percent complete: 15.1%; Average loss: 4.3002
# Iteration: 606; Percent complete: 15.2%; Average loss: 4.0112
# Iteration: 607; Percent complete: 15.2%; Average loss: 4.0644
# Iteration: 608; Percent complete: 15.2%; Average loss: 3.4559
# Iteration: 609; Percent complete: 15.2%; Average loss: 4.3363
# Iteration: 610; Percent complete: 15.2%; Average loss: 4.1160
# Iteration: 611; Percent complete: 15.3%; Average loss: 4.1578
# Iteration: 612; Percent complete: 15.3%; Average loss: 3.8888
# Iteration: 613; Percent complete: 15.3%; Average loss: 4.3737
# Iteration: 614; Percent complete: 15.3%; Average loss: 3.9753
# Iteration: 615; Percent complete: 15.4%; Average loss: 3.7404
# Iteration: 616; Percent complete: 15.4%; Average loss: 4.3051
# Iteration: 617; Percent complete: 15.4%; Average loss: 3.4036
# Iteration: 618; Percent complete: 15.4%; Average loss: 3.9698
# Iteration: 619; Percent complete: 15.5%; Average loss: 3.7326
# Iteration: 620; Percent complete: 15.5%; Average loss: 3.9595
# Iteration: 621; Percent complete: 15.5%; Average loss: 3.8671
# Iteration: 622; Percent complete: 15.6%; Average loss: 3.6599
# Iteration: 623; Percent complete: 15.6%; Average loss: 4.3379
# Iteration: 624; Percent complete: 15.6%; Average loss: 4.0803
# Iteration: 625; Percent complete: 15.6%; Average loss: 3.5652
# Iteration: 626; Percent complete: 15.7%; Average loss: 3.5334
# Iteration: 627; Percent complete: 15.7%; Average loss: 3.6830
# Iteration: 628; Percent complete: 15.7%; Average loss: 4.0156
# Iteration: 629; Percent complete: 15.7%; Average loss: 4.0110
# Iteration: 630; Percent complete: 15.8%; Average loss: 4.2192
# Iteration: 631; Percent complete: 15.8%; Average loss: 4.4113
# Iteration: 632; Percent complete: 15.8%; Average loss: 3.7217
# Iteration: 633; Percent complete: 15.8%; Average loss: 4.3482
# Iteration: 634; Percent complete: 15.8%; Average loss: 3.7015
# Iteration: 635; Percent complete: 15.9%; Average loss: 3.9972
# Iteration: 636; Percent complete: 15.9%; Average loss: 3.9493
# Iteration: 637; Percent complete: 15.9%; Average loss: 4.1402
# Iteration: 638; Percent complete: 16.0%; Average loss: 4.0638
# Iteration: 639; Percent complete: 16.0%; Average loss: 4.6063
# Iteration: 640; Percent complete: 16.0%; Average loss: 3.8728
# Iteration: 641; Percent complete: 16.0%; Average loss: 4.0172
# Iteration: 642; Percent complete: 16.1%; Average loss: 3.6233
# Iteration: 643; Percent complete: 16.1%; Average loss: 3.8186
# Iteration: 644; Percent complete: 16.1%; Average loss: 3.8615
# Iteration: 645; Percent complete: 16.1%; Average loss: 4.4109
# Iteration: 646; Percent complete: 16.2%; Average loss: 3.9330
# Iteration: 647; Percent complete: 16.2%; Average loss: 3.5073
# Iteration: 648; Percent complete: 16.2%; Average loss: 3.9063
# Iteration: 649; Percent complete: 16.2%; Average loss: 4.4240
# Iteration: 650; Percent complete: 16.2%; Average loss: 4.8480
# Iteration: 651; Percent complete: 16.3%; Average loss: 3.8476
# Iteration: 652; Percent complete: 16.3%; Average loss: 3.3608
# Iteration: 653; Percent complete: 16.3%; Average loss: 4.1201
# Iteration: 654; Percent complete: 16.4%; Average loss: 4.3862
# Iteration: 655; Percent complete: 16.4%; Average loss: 3.6075
# Iteration: 656; Percent complete: 16.4%; Average loss: 3.5083
# Iteration: 657; Percent complete: 16.4%; Average loss: 4.0020
# Iteration: 658; Percent complete: 16.4%; Average loss: 3.9807
# Iteration: 659; Percent complete: 16.5%; Average loss: 4.1292
# Iteration: 660; Percent complete: 16.5%; Average loss: 3.6844
# Iteration: 661; Percent complete: 16.5%; Average loss: 3.9851
# Iteration: 662; Percent complete: 16.6%; Average loss: 4.1684
# Iteration: 663; Percent complete: 16.6%; Average loss: 4.2563
# Iteration: 664; Percent complete: 16.6%; Average loss: 4.2635
# Iteration: 665; Percent complete: 16.6%; Average loss: 4.0587
# Iteration: 666; Percent complete: 16.7%; Average loss: 4.0978
# Iteration: 667; Percent complete: 16.7%; Average loss: 4.2786
# Iteration: 668; Percent complete: 16.7%; Average loss: 3.7650
# Iteration: 669; Percent complete: 16.7%; Average loss: 4.1534
# Iteration: 670; Percent complete: 16.8%; Average loss: 4.0174
# Iteration: 671; Percent complete: 16.8%; Average loss: 3.8818
# Iteration: 672; Percent complete: 16.8%; Average loss: 3.8129
# Iteration: 673; Percent complete: 16.8%; Average loss: 3.7885
# Iteration: 674; Percent complete: 16.9%; Average loss: 4.4076
# Iteration: 675; Percent complete: 16.9%; Average loss: 3.9471
# Iteration: 676; Percent complete: 16.9%; Average loss: 4.2266
# Iteration: 677; Percent complete: 16.9%; Average loss: 3.2806
# Iteration: 678; Percent complete: 17.0%; Average loss: 4.6714
# Iteration: 679; Percent complete: 17.0%; Average loss: 3.8416
# Iteration: 680; Percent complete: 17.0%; Average loss: 4.2343
# Iteration: 681; Percent complete: 17.0%; Average loss: 3.9652
# Iteration: 682; Percent complete: 17.1%; Average loss: 3.4231
# Iteration: 683; Percent complete: 17.1%; Average loss: 3.6084
# Iteration: 684; Percent complete: 17.1%; Average loss: 3.7296
# Iteration: 685; Percent complete: 17.1%; Average loss: 3.9893
# Iteration: 686; Percent complete: 17.2%; Average loss: 3.7339
# Iteration: 687; Percent complete: 17.2%; Average loss: 4.2852
# Iteration: 688; Percent complete: 17.2%; Average loss: 4.4978
# Iteration: 689; Percent complete: 17.2%; Average loss: 4.2602
# Iteration: 690; Percent complete: 17.2%; Average loss: 3.8385
# Iteration: 691; Percent complete: 17.3%; Average loss: 4.4499
# Iteration: 692; Percent complete: 17.3%; Average loss: 3.9569
# Iteration: 693; Percent complete: 17.3%; Average loss: 4.0251
# Iteration: 694; Percent complete: 17.3%; Average loss: 4.3333
# Iteration: 695; Percent complete: 17.4%; Average loss: 3.7701
# Iteration: 696; Percent complete: 17.4%; Average loss: 4.3506
# Iteration: 697; Percent complete: 17.4%; Average loss: 4.0178
# Iteration: 698; Percent complete: 17.4%; Average loss: 4.2152
# Iteration: 699; Percent complete: 17.5%; Average loss: 3.8676
# Iteration: 700; Percent complete: 17.5%; Average loss: 3.6375
# Iteration: 701; Percent complete: 17.5%; Average loss: 4.4289
# Iteration: 702; Percent complete: 17.5%; Average loss: 4.4014
# Iteration: 703; Percent complete: 17.6%; Average loss: 4.0216
# Iteration: 704; Percent complete: 17.6%; Average loss: 4.2409
# Iteration: 705; Percent complete: 17.6%; Average loss: 3.4939
# Iteration: 706; Percent complete: 17.6%; Average loss: 3.7110
# Iteration: 707; Percent complete: 17.7%; Average loss: 4.2722
# Iteration: 708; Percent complete: 17.7%; Average loss: 4.3255
# Iteration: 709; Percent complete: 17.7%; Average loss: 4.3496
# Iteration: 710; Percent complete: 17.8%; Average loss: 3.9037
# Iteration: 711; Percent complete: 17.8%; Average loss: 4.2899
# Iteration: 712; Percent complete: 17.8%; Average loss: 3.3005
# Iteration: 713; Percent complete: 17.8%; Average loss: 3.8773
# Iteration: 714; Percent complete: 17.8%; Average loss: 4.4700
# Iteration: 715; Percent complete: 17.9%; Average loss: 4.2447
# Iteration: 716; Percent complete: 17.9%; Average loss: 3.8533
# Iteration: 717; Percent complete: 17.9%; Average loss: 4.0317
# Iteration: 718; Percent complete: 17.9%; Average loss: 3.6529
# Iteration: 719; Percent complete: 18.0%; Average loss: 3.9854
# Iteration: 720; Percent complete: 18.0%; Average loss: 4.2886
# Iteration: 721; Percent complete: 18.0%; Average loss: 3.4512
# Iteration: 722; Percent complete: 18.1%; Average loss: 4.0403
# Iteration: 723; Percent complete: 18.1%; Average loss: 3.9159
# Iteration: 724; Percent complete: 18.1%; Average loss: 4.0985
# Iteration: 725; Percent complete: 18.1%; Average loss: 3.7688
# Iteration: 726; Percent complete: 18.1%; Average loss: 3.9904
# Iteration: 727; Percent complete: 18.2%; Average loss: 3.3209
# Iteration: 728; Percent complete: 18.2%; Average loss: 4.2659
# Iteration: 729; Percent complete: 18.2%; Average loss: 3.9970
# Iteration: 730; Percent complete: 18.2%; Average loss: 3.7750
# Iteration: 731; Percent complete: 18.3%; Average loss: 4.3370
# Iteration: 732; Percent complete: 18.3%; Average loss: 3.8388
# Iteration: 733; Percent complete: 18.3%; Average loss: 3.9862
# Iteration: 734; Percent complete: 18.4%; Average loss: 3.5069
# Iteration: 735; Percent complete: 18.4%; Average loss: 3.9859
# Iteration: 736; Percent complete: 18.4%; Average loss: 3.9588
# Iteration: 737; Percent complete: 18.4%; Average loss: 3.3505
# Iteration: 738; Percent complete: 18.4%; Average loss: 4.2654
# Iteration: 739; Percent complete: 18.5%; Average loss: 3.4389
# Iteration: 740; Percent complete: 18.5%; Average loss: 4.0078
# Iteration: 741; Percent complete: 18.5%; Average loss: 3.8959
# Iteration: 742; Percent complete: 18.6%; Average loss: 3.8586
# Iteration: 743; Percent complete: 18.6%; Average loss: 3.9688
# Iteration: 744; Percent complete: 18.6%; Average loss: 4.0766
# Iteration: 745; Percent complete: 18.6%; Average loss: 4.0701
# Iteration: 746; Percent complete: 18.6%; Average loss: 4.3564
# Iteration: 747; Percent complete: 18.7%; Average loss: 3.8413
# Iteration: 748; Percent complete: 18.7%; Average loss: 4.0448
# Iteration: 749; Percent complete: 18.7%; Average loss: 3.8803
# Iteration: 750; Percent complete: 18.8%; Average loss: 4.4193
# Iteration: 751; Percent complete: 18.8%; Average loss: 2.9778
# Iteration: 752; Percent complete: 18.8%; Average loss: 3.9798
# Iteration: 753; Percent complete: 18.8%; Average loss: 3.9002
# Iteration: 754; Percent complete: 18.9%; Average loss: 4.1688
# Iteration: 755; Percent complete: 18.9%; Average loss: 4.0342
# Iteration: 756; Percent complete: 18.9%; Average loss: 4.3030
# Iteration: 757; Percent complete: 18.9%; Average loss: 3.2485
# Iteration: 758; Percent complete: 18.9%; Average loss: 4.0314
# Iteration: 759; Percent complete: 19.0%; Average loss: 4.0949
# Iteration: 760; Percent complete: 19.0%; Average loss: 4.0489
# Iteration: 761; Percent complete: 19.0%; Average loss: 4.1430
# Iteration: 762; Percent complete: 19.1%; Average loss: 4.0278
# Iteration: 763; Percent complete: 19.1%; Average loss: 4.1214
# Iteration: 764; Percent complete: 19.1%; Average loss: 3.7298
# Iteration: 765; Percent complete: 19.1%; Average loss: 3.7090
# Iteration: 766; Percent complete: 19.1%; Average loss: 3.8912
# Iteration: 767; Percent complete: 19.2%; Average loss: 3.3209
# Iteration: 768; Percent complete: 19.2%; Average loss: 4.2498
# Iteration: 769; Percent complete: 19.2%; Average loss: 3.8365
# Iteration: 770; Percent complete: 19.2%; Average loss: 4.5289
# Iteration: 771; Percent complete: 19.3%; Average loss: 3.8578
# Iteration: 772; Percent complete: 19.3%; Average loss: 4.2320
# Iteration: 773; Percent complete: 19.3%; Average loss: 4.1339
# Iteration: 774; Percent complete: 19.4%; Average loss: 3.6723
# Iteration: 775; Percent complete: 19.4%; Average loss: 4.1661
# Iteration: 776; Percent complete: 19.4%; Average loss: 4.0355
# Iteration: 777; Percent complete: 19.4%; Average loss: 3.5309
# Iteration: 778; Percent complete: 19.4%; Average loss: 3.9734
# Iteration: 779; Percent complete: 19.5%; Average loss: 3.8226
# Iteration: 780; Percent complete: 19.5%; Average loss: 3.8021
# Iteration: 781; Percent complete: 19.5%; Average loss: 4.0897
# ...
# Iteration: 3748; Percent complete: 93.7%; Average loss: 3.3059
# Iteration: 3749; Percent complete: 93.7%; Average loss: 3.2127
# Iteration: 3750; Percent complete: 93.8%; Average loss: 3.2877
# Iteration: 3751; Percent complete: 93.8%; Average loss: 3.5238
# Iteration: 3752; Percent complete: 93.8%; Average loss: 3.0723
# Iteration: 3753; Percent complete: 93.8%; Average loss: 3.4614
# Iteration: 3754; Percent complete: 93.8%; Average loss: 3.1132
# Iteration: 3755; Percent complete: 93.9%; Average loss: 3.8481
# Iteration: 3756; Percent complete: 93.9%; Average loss: 3.4525
# Iteration: 3757; Percent complete: 93.9%; Average loss: 3.0175
# Iteration: 3758; Percent complete: 94.0%; Average loss: 3.7011
# Iteration: 3759; Percent complete: 94.0%; Average loss: 3.7431
# Iteration: 3760; Percent complete: 94.0%; Average loss: 3.3288
# Iteration: 3761; Percent complete: 94.0%; Average loss: 3.6896
# Iteration: 3762; Percent complete: 94.0%; Average loss: 3.0193
# Iteration: 3763; Percent complete: 94.1%; Average loss: 3.6298
# Iteration: 3764; Percent complete: 94.1%; Average loss: 2.9498
# Iteration: 3765; Percent complete: 94.1%; Average loss: 3.0086
# Iteration: 3766; Percent complete: 94.2%; Average loss: 3.0662
# Iteration: 3767; Percent complete: 94.2%; Average loss: 3.0659
# Iteration: 3768; Percent complete: 94.2%; Average loss: 3.3642
# Iteration: 3769; Percent complete: 94.2%; Average loss: 3.5096
# Iteration: 3770; Percent complete: 94.2%; Average loss: 3.4336
# Iteration: 3771; Percent complete: 94.3%; Average loss: 3.5746
# Iteration: 3772; Percent complete: 94.3%; Average loss: 3.5252
# Iteration: 3773; Percent complete: 94.3%; Average loss: 3.2076
# Iteration: 3774; Percent complete: 94.3%; Average loss: 4.1970
# Iteration: 3775; Percent complete: 94.4%; Average loss: 2.6482
# Iteration: 3776; Percent complete: 94.4%; Average loss: 3.1249
# Iteration: 3777; Percent complete: 94.4%; Average loss: 3.5030
# Iteration: 3778; Percent complete: 94.5%; Average loss: 2.7125
# Iteration: 3779; Percent complete: 94.5%; Average loss: 3.3466
# Iteration: 3780; Percent complete: 94.5%; Average loss: 3.1055
# Iteration: 3781; Percent complete: 94.5%; Average loss: 3.4546
# Iteration: 3782; Percent complete: 94.5%; Average loss: 3.5251
# Iteration: 3783; Percent complete: 94.6%; Average loss: 2.9622
# Iteration: 3784; Percent complete: 94.6%; Average loss: 3.5424
# Iteration: 3785; Percent complete: 94.6%; Average loss: 3.2655
# Iteration: 3786; Percent complete: 94.7%; Average loss: 3.1934
# Iteration: 3787; Percent complete: 94.7%; Average loss: 3.6050
# Iteration: 3788; Percent complete: 94.7%; Average loss: 3.5107
# Iteration: 3789; Percent complete: 94.7%; Average loss: 2.5967
# Iteration: 3790; Percent complete: 94.8%; Average loss: 3.4375
# Iteration: 3791; Percent complete: 94.8%; Average loss: 3.6358
# Iteration: 3792; Percent complete: 94.8%; Average loss: 3.4166
# Iteration: 3793; Percent complete: 94.8%; Average loss: 2.8734
# Iteration: 3794; Percent complete: 94.8%; Average loss: 3.3430
# Iteration: 3795; Percent complete: 94.9%; Average loss: 3.2200
# Iteration: 3796; Percent complete: 94.9%; Average loss: 3.1401
# Iteration: 3797; Percent complete: 94.9%; Average loss: 3.4735
# Iteration: 3798; Percent complete: 95.0%; Average loss: 3.2315
# Iteration: 3799; Percent complete: 95.0%; Average loss: 3.3486
# Iteration: 3800; Percent complete: 95.0%; Average loss: 3.6961
# Iteration: 3801; Percent complete: 95.0%; Average loss: 2.8793
# Iteration: 3802; Percent complete: 95.0%; Average loss: 3.5201
# Iteration: 3803; Percent complete: 95.1%; Average loss: 3.3932
# Iteration: 3804; Percent complete: 95.1%; Average loss: 3.5988
# Iteration: 3805; Percent complete: 95.1%; Average loss: 3.6578
# Iteration: 3806; Percent complete: 95.2%; Average loss: 2.8853
# Iteration: 3807; Percent complete: 95.2%; Average loss: 3.1894
# Iteration: 3808; Percent complete: 95.2%; Average loss: 3.2454
# Iteration: 3809; Percent complete: 95.2%; Average loss: 3.6291
# Iteration: 3810; Percent complete: 95.2%; Average loss: 2.4660
# Iteration: 3811; Percent complete: 95.3%; Average loss: 3.2188
# Iteration: 3812; Percent complete: 95.3%; Average loss: 3.4149
# Iteration: 3813; Percent complete: 95.3%; Average loss: 3.1330
# Iteration: 3814; Percent complete: 95.3%; Average loss: 3.4684
# Iteration: 3815; Percent complete: 95.4%; Average loss: 2.9527
# Iteration: 3816; Percent complete: 95.4%; Average loss: 3.8747
# Iteration: 3817; Percent complete: 95.4%; Average loss: 2.9727
# Iteration: 3818; Percent complete: 95.5%; Average loss: 3.9113
# Iteration: 3819; Percent complete: 95.5%; Average loss: 3.8123
# Iteration: 3820; Percent complete: 95.5%; Average loss: 3.6451
# Iteration: 3821; Percent complete: 95.5%; Average loss: 2.7169
# Iteration: 3822; Percent complete: 95.5%; Average loss: 3.4347
# Iteration: 3823; Percent complete: 95.6%; Average loss: 3.4819
# Iteration: 3824; Percent complete: 95.6%; Average loss: 2.9711
# Iteration: 3825; Percent complete: 95.6%; Average loss: 3.5123
# Iteration: 3826; Percent complete: 95.7%; Average loss: 3.3314
# Iteration: 3827; Percent complete: 95.7%; Average loss: 3.3001
# Iteration: 3828; Percent complete: 95.7%; Average loss: 4.0097
# Iteration: 3829; Percent complete: 95.7%; Average loss: 3.8230
# Iteration: 3830; Percent complete: 95.8%; Average loss: 3.8520
# Iteration: 3831; Percent complete: 95.8%; Average loss: 3.2586
# Iteration: 3832; Percent complete: 95.8%; Average loss: 3.4287
# Iteration: 3833; Percent complete: 95.8%; Average loss: 3.4184
# Iteration: 3834; Percent complete: 95.9%; Average loss: 3.3937
# Iteration: 3835; Percent complete: 95.9%; Average loss: 3.2398
# Iteration: 3836; Percent complete: 95.9%; Average loss: 2.9952
# Iteration: 3837; Percent complete: 95.9%; Average loss: 3.0997
# Iteration: 3838; Percent complete: 96.0%; Average loss: 2.9490
# Iteration: 3839; Percent complete: 96.0%; Average loss: 2.9083
# Iteration: 3840; Percent complete: 96.0%; Average loss: 3.3422
# Iteration: 3841; Percent complete: 96.0%; Average loss: 3.5042
# Iteration: 3842; Percent complete: 96.0%; Average loss: 3.8667
# Iteration: 3843; Percent complete: 96.1%; Average loss: 3.1306
# Iteration: 3844; Percent complete: 96.1%; Average loss: 3.4588
# Iteration: 3845; Percent complete: 96.1%; Average loss: 3.0903
# Iteration: 3846; Percent complete: 96.2%; Average loss: 3.0975
# Iteration: 3847; Percent complete: 96.2%; Average loss: 4.0195
# Iteration: 3848; Percent complete: 96.2%; Average loss: 3.0572
# Iteration: 3849; Percent complete: 96.2%; Average loss: 3.8392
# Iteration: 3850; Percent complete: 96.2%; Average loss: 3.7928
# Iteration: 3851; Percent complete: 96.3%; Average loss: 3.5003
# Iteration: 3852; Percent complete: 96.3%; Average loss: 3.5517
# Iteration: 3853; Percent complete: 96.3%; Average loss: 2.9162
# Iteration: 3854; Percent complete: 96.4%; Average loss: 3.3723
# Iteration: 3855; Percent complete: 96.4%; Average loss: 3.5637
# Iteration: 3856; Percent complete: 96.4%; Average loss: 2.9287
# Iteration: 3857; Percent complete: 96.4%; Average loss: 3.4732
# Iteration: 3858; Percent complete: 96.5%; Average loss: 3.3242
# Iteration: 3859; Percent complete: 96.5%; Average loss: 2.9762
# Iteration: 3860; Percent complete: 96.5%; Average loss: 2.9449
# Iteration: 3861; Percent complete: 96.5%; Average loss: 3.4992
# Iteration: 3862; Percent complete: 96.5%; Average loss: 2.9175
# Iteration: 3863; Percent complete: 96.6%; Average loss: 4.3645
# Iteration: 3864; Percent complete: 96.6%; Average loss: 2.9346
# Iteration: 3865; Percent complete: 96.6%; Average loss: 3.3994
# Iteration: 3866; Percent complete: 96.7%; Average loss: 3.2864
# Iteration: 3867; Percent complete: 96.7%; Average loss: 3.0170
# Iteration: 3868; Percent complete: 96.7%; Average loss: 3.2739
# Iteration: 3869; Percent complete: 96.7%; Average loss: 3.8855
# Iteration: 3870; Percent complete: 96.8%; Average loss: 3.2277
# Iteration: 3871; Percent complete: 96.8%; Average loss: 3.9506
# Iteration: 3872; Percent complete: 96.8%; Average loss: 3.8083
# Iteration: 3873; Percent complete: 96.8%; Average loss: 3.2243
# Iteration: 3874; Percent complete: 96.9%; Average loss: 3.4224
# Iteration: 3875; Percent complete: 96.9%; Average loss: 3.1839
# Iteration: 3876; Percent complete: 96.9%; Average loss: 2.7301
# Iteration: 3877; Percent complete: 96.9%; Average loss: 3.6975
# Iteration: 3878; Percent complete: 97.0%; Average loss: 3.0826
# Iteration: 3879; Percent complete: 97.0%; Average loss: 3.2373
# Iteration: 3880; Percent complete: 97.0%; Average loss: 3.0550
# Iteration: 3881; Percent complete: 97.0%; Average loss: 3.3758
# Iteration: 3882; Percent complete: 97.0%; Average loss: 3.7059
# Iteration: 3883; Percent complete: 97.1%; Average loss: 3.1689
# Iteration: 3884; Percent complete: 97.1%; Average loss: 3.3410
# Iteration: 3885; Percent complete: 97.1%; Average loss: 3.0883
# Iteration: 3886; Percent complete: 97.2%; Average loss: 3.6893
# Iteration: 3887; Percent complete: 97.2%; Average loss: 3.5201
# Iteration: 3888; Percent complete: 97.2%; Average loss: 3.6234
# Iteration: 3889; Percent complete: 97.2%; Average loss: 3.1014
# Iteration: 3890; Percent complete: 97.2%; Average loss: 3.7915
# Iteration: 3891; Percent complete: 97.3%; Average loss: 3.0902
# Iteration: 3892; Percent complete: 97.3%; Average loss: 3.2153
# Iteration: 3893; Percent complete: 97.3%; Average loss: 3.3801
# Iteration: 3894; Percent complete: 97.4%; Average loss: 3.1416
# Iteration: 3895; Percent complete: 97.4%; Average loss: 2.6287
# Iteration: 3896; Percent complete: 97.4%; Average loss: 3.3875
# Iteration: 3897; Percent complete: 97.4%; Average loss: 2.7873
# Iteration: 3898; Percent complete: 97.5%; Average loss: 2.9964
# Iteration: 3899; Percent complete: 97.5%; Average loss: 3.0783
# Iteration: 3900; Percent complete: 97.5%; Average loss: 3.7592
# Iteration: 3901; Percent complete: 97.5%; Average loss: 3.3492
# Iteration: 3902; Percent complete: 97.5%; Average loss: 2.9632
# Iteration: 3903; Percent complete: 97.6%; Average loss: 3.0940
# Iteration: 3904; Percent complete: 97.6%; Average loss: 3.6381
# Iteration: 3905; Percent complete: 97.6%; Average loss: 3.0936
# Iteration: 3906; Percent complete: 97.7%; Average loss: 3.6536
# Iteration: 3907; Percent complete: 97.7%; Average loss: 2.7696
# Iteration: 3908; Percent complete: 97.7%; Average loss: 3.7605
# Iteration: 3909; Percent complete: 97.7%; Average loss: 3.2017
# Iteration: 3910; Percent complete: 97.8%; Average loss: 3.1374
# Iteration: 3911; Percent complete: 97.8%; Average loss: 3.5267
# Iteration: 3912; Percent complete: 97.8%; Average loss: 3.6123
# Iteration: 3913; Percent complete: 97.8%; Average loss: 3.1890
# Iteration: 3914; Percent complete: 97.9%; Average loss: 3.3812
# Iteration: 3915; Percent complete: 97.9%; Average loss: 3.4283
# Iteration: 3916; Percent complete: 97.9%; Average loss: 3.5520
# Iteration: 3917; Percent complete: 97.9%; Average loss: 3.1351
# Iteration: 3918; Percent complete: 98.0%; Average loss: 2.9361
# Iteration: 3919; Percent complete: 98.0%; Average loss: 3.6124
# Iteration: 3920; Percent complete: 98.0%; Average loss: 3.1242
# Iteration: 3921; Percent complete: 98.0%; Average loss: 3.4268
# Iteration: 3922; Percent complete: 98.0%; Average loss: 3.3236
# Iteration: 3923; Percent complete: 98.1%; Average loss: 3.3012
# Iteration: 3924; Percent complete: 98.1%; Average loss: 3.1289
# Iteration: 3925; Percent complete: 98.1%; Average loss: 2.6567
# Iteration: 3926; Percent complete: 98.2%; Average loss: 3.5994
# Iteration: 3927; Percent complete: 98.2%; Average loss: 3.5700
# Iteration: 3928; Percent complete: 98.2%; Average loss: 2.7626
# Iteration: 3929; Percent complete: 98.2%; Average loss: 2.8593
# Iteration: 3930; Percent complete: 98.2%; Average loss: 3.5527
# Iteration: 3931; Percent complete: 98.3%; Average loss: 3.4346
# Iteration: 3932; Percent complete: 98.3%; Average loss: 3.6096
# Iteration: 3933; Percent complete: 98.3%; Average loss: 3.2350
# Iteration: 3934; Percent complete: 98.4%; Average loss: 3.0662
# Iteration: 3935; Percent complete: 98.4%; Average loss: 3.0537
# Iteration: 3936; Percent complete: 98.4%; Average loss: 3.2358
# Iteration: 3937; Percent complete: 98.4%; Average loss: 3.7456
# Iteration: 3938; Percent complete: 98.5%; Average loss: 3.3748
# Iteration: 3939; Percent complete: 98.5%; Average loss: 3.1114
# Iteration: 3940; Percent complete: 98.5%; Average loss: 3.4257
# Iteration: 3941; Percent complete: 98.5%; Average loss: 3.3677
# Iteration: 3942; Percent complete: 98.6%; Average loss: 3.6368
# Iteration: 3943; Percent complete: 98.6%; Average loss: 3.2465
# Iteration: 3944; Percent complete: 98.6%; Average loss: 3.9861
# Iteration: 3945; Percent complete: 98.6%; Average loss: 3.2810
# Iteration: 3946; Percent complete: 98.7%; Average loss: 3.3347
# Iteration: 3947; Percent complete: 98.7%; Average loss: 3.1353
# Iteration: 3948; Percent complete: 98.7%; Average loss: 2.9315
# Iteration: 3949; Percent complete: 98.7%; Average loss: 2.9986
# Iteration: 3950; Percent complete: 98.8%; Average loss: 3.1329
# Iteration: 3951; Percent complete: 98.8%; Average loss: 3.5438
# Iteration: 3952; Percent complete: 98.8%; Average loss: 3.2596
# Iteration: 3953; Percent complete: 98.8%; Average loss: 3.8257
# Iteration: 3954; Percent complete: 98.9%; Average loss: 3.1367
# Iteration: 3955; Percent complete: 98.9%; Average loss: 3.0618
# Iteration: 3956; Percent complete: 98.9%; Average loss: 2.8168
# Iteration: 3957; Percent complete: 98.9%; Average loss: 3.0080
# Iteration: 3958; Percent complete: 99.0%; Average loss: 3.0120
# Iteration: 3959; Percent complete: 99.0%; Average loss: 3.4565
# Iteration: 3960; Percent complete: 99.0%; Average loss: 3.4160
# Iteration: 3961; Percent complete: 99.0%; Average loss: 2.8295
# Iteration: 3962; Percent complete: 99.1%; Average loss: 3.8394
# Iteration: 3963; Percent complete: 99.1%; Average loss: 3.2273
# Iteration: 3964; Percent complete: 99.1%; Average loss: 3.6149
# Iteration: 3965; Percent complete: 99.1%; Average loss: 3.3145
# Iteration: 3966; Percent complete: 99.2%; Average loss: 3.3276
# Iteration: 3967; Percent complete: 99.2%; Average loss: 3.6255
# Iteration: 3968; Percent complete: 99.2%; Average loss: 3.0743
# Iteration: 3969; Percent complete: 99.2%; Average loss: 3.3812
# Iteration: 3970; Percent complete: 99.2%; Average loss: 3.2282
# Iteration: 3971; Percent complete: 99.3%; Average loss: 3.1318
# Iteration: 3972; Percent complete: 99.3%; Average loss: 3.1087
# Iteration: 3973; Percent complete: 99.3%; Average loss: 3.2943
# Iteration: 3974; Percent complete: 99.4%; Average loss: 3.0766
# Iteration: 3975; Percent complete: 99.4%; Average loss: 2.8989
# Iteration: 3976; Percent complete: 99.4%; Average loss: 2.9601
# Iteration: 3977; Percent complete: 99.4%; Average loss: 3.1252
# Iteration: 3978; Percent complete: 99.5%; Average loss: 3.1828
# Iteration: 3979; Percent complete: 99.5%; Average loss: 2.8634
# Iteration: 3980; Percent complete: 99.5%; Average loss: 3.3450
# Iteration: 3981; Percent complete: 99.5%; Average loss: 3.6023
# Iteration: 3982; Percent complete: 99.6%; Average loss: 3.3185
# Iteration: 3983; Percent complete: 99.6%; Average loss: 3.4861
# Iteration: 3984; Percent complete: 99.6%; Average loss: 3.4162
# Iteration: 3985; Percent complete: 99.6%; Average loss: 2.9128
# Iteration: 3986; Percent complete: 99.7%; Average loss: 3.6950
# Iteration: 3987; Percent complete: 99.7%; Average loss: 3.0226
# Iteration: 3988; Percent complete: 99.7%; Average loss: 3.1757
# Iteration: 3989; Percent complete: 99.7%; Average loss: 3.2682
# Iteration: 3990; Percent complete: 99.8%; Average loss: 3.1562
# Iteration: 3991; Percent complete: 99.8%; Average loss: 3.4218
# Iteration: 3992; Percent complete: 99.8%; Average loss: 3.1460
# Iteration: 3993; Percent complete: 99.8%; Average loss: 3.6768
# Iteration: 3994; Percent complete: 99.9%; Average loss: 2.4346
# Iteration: 3995; Percent complete: 99.9%; Average loss: 3.0635
# Iteration: 3996; Percent complete: 99.9%; Average loss: 3.1742
# Iteration: 3997; Percent complete: 99.9%; Average loss: 3.3598
# Iteration: 3998; Percent complete: 100.0%; Average loss: 2.8966
# Iteration: 3999; Percent complete: 100.0%; Average loss: 3.1610
# Iteration: 4000; Percent complete: 100.0%; Average loss: 3.7265

# %%
len(l)
# Out:
# 4000

# %%
print("Minimum loss achieved in {0} iteration is {1} ".format(l.index(min(l)),min(l)))
# Out:
# Minimum loss achieved in 3277 iteration is 2.285989761352539

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot([*range(len(l))],l)
plt.title('loss vs iterations')
plt.xlabel('xAxis name')
plt.ylabel('yAxis name')
plt.show()

# %%
l[]
